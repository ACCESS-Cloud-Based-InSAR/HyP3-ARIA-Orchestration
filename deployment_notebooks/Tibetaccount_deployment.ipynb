# %% [markdown]
# This is to demonstrate how to use the `s1-enumerator` to get a full time series of GUNWs.
#
# We are going basically take each month in acceptable date range and increment by a month and make sure the temporal window is large enough to ensure connectivity across data gaps.

# %% [markdown]
# # Parameters
#
# This is what the operator is going to have to change. Will provide some comments.

# %%
# toggle user-controlled parameters here
import datetime
import json

# product cutline
aoi_shapefile = '../aois/TibetA_pathNumber165.geojson'
# load AO geojson and strip variables
with open(aoi_shapefile, 'r') as file:
    data = json.load(file)
    json_keys = data['features'][0]['properties'].keys()
    # assign local variables from dict
    locals().update(data['features'][0]['properties'])

# Override metadata keys
# Warning, toggle with caution
# Only to be used if you are testing and intentionally updating AO geojsons
update_AO = True

### Spatial coverage constraint parameter 'azimuth_mismatch'
# The merged SLC area over the AOI is allowed to be smaller by 'azimuth_mismatch' x swath width (i.e. 250km)
if 'azimuth_mismatch' not in json_keys or update_AO:
    azimuth_mismatch = 50 # adjust as necessary
    data['features'][0]['properties']['azimuth_mismatch'] = azimuth_mismatch

# Specify deployment URL
deploy_url = 'https://hyp3-tibet.asf.alaska.edu' #for Tibet
#deploy_url = 'https://hyp3-isce.asf.alaska.edu' #for access
data['features'][0]['properties']['deploy_url'] = deploy_url

# Number of nearest neighbors
if 'num_neighbors' not in json_keys or update_AO:
    num_neighbors = 2 # adjust as necessary
    data['features'][0]['properties']['num_neighbors'] = num_neighbors

#set temporal parameters
if 'min_days_backward' not in json_keys or update_AO:
    min_days_backward = 0
    data['features'][0]['properties']['min_days_backward'] = min_days_backward
today = datetime.datetime.now()
# Earliest year for reference frames
START_YEAR = 2014
# Latest year for reference frames
END_YEAR = today.year
# Adjust depending on seasonality
# For annual IFGs, select a single months of interest and you will get what you want.
if 'month_range_lower' not in json_keys or update_AO:
    month_range_lower = 1 # adjust as necessary
    data['features'][0]['properties']['month_range_lower'] = month_range_lower
if 'month_range_upper' not in json_keys or update_AO:
    month_range_upper = 12 # adjust as necessary
    data['features'][0]['properties']['month_range_upper'] = month_range_upper
MONTHS_OF_INTEREST = list(range(month_range_lower,month_range_upper+1))


# Define job-name
if 'job_name' not in json_keys or update_AO:
    job_name = aoi_shapefile.split('/')[-1].split('.')[0].split('pathNumber')
    job_name = ''.join(job_name)
    job_name = job_name[-20:]
    data['features'][0]['properties']['job_name'] = job_name
# product directory
prod_dir = job_name

# if operator variables do not exist, set and populate geojson with them
with open(aoi_shapefile, 'w') as file:
    json.dump(data, file)

# %%
from s1_enumerator import get_aoi_dataframe,  distill_all_pairs, enumerate_ifgs, get_s1_coverage_tiles, enumerate_ifgs_from_stack, get_s1_stack_by_dataframe
import concurrent
from rasterio.crs import CRS
from s1_enumerator import duplicate_gunw_found
from tqdm import tqdm
from shapely.geometry import Point, shape
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import numpy as np
from dateutil.relativedelta import relativedelta
import networkx as nx
import boto3
import hyp3_sdk
import copy

# %%
def shapefile_area(file_bbox,
        bounds = False):
    """Compute km\u00b2 area of shapefile."""
    # import dependencies
    from pyproj import Proj

    # loop through polygons
    shape_area = 0
    # pass single polygon as list
    if file_bbox.type == 'Polygon': file_bbox = [file_bbox]
    for polyobj in file_bbox:
        #first check if empty
        if polyobj.is_empty:
            shape_area += 0
            continue
        # get coords
        if bounds:
            # Pass coordinates of bounds as opposed to cutline
            # Necessary for estimating DEM/mask footprints
            WSEN = polyobj.bounds
            lon = np.array([WSEN[0],WSEN[0],WSEN[2],WSEN[2],WSEN[0]])
            lat = np.array([WSEN[1],WSEN[3],WSEN[3],WSEN[1],WSEN[1]])
        else:
            lon, lat = polyobj.exterior.coords.xy

        # use equal area projection centered on/bracketing AOI
        pa = Proj("+proj=aea +lat_1={} +lat_2={} +lat_0={} +lon_0={}". \
             format(min(lat), max(lat), (max(lat)+min(lat))/2, \
             (max(lon)+min(lon))/2))
        x, y = pa(lon, lat)
        cop = {"type": "Polygon", "coordinates": [zip(x, y)]}
        shape_area += shape(cop).area/1e6  # area in km^2

    return shape_area

# %%
def continuous_time(product_df, iter_id='fileID'):
    """
    Split the products into spatiotemporally continuous groups.
    Split products by individual, continuous interferograms.
    Input must be already sorted by pair and start-time to fit
    the logic scheme below.
    Using their time-tags, this function determines whether or not
    successive products are in the same orbit.
    If in the same orbit, the program determines whether or not they
    overlap in time and are therefore spatially contiguous,
    and rejects/reports cases for which there is no temporal overlap
    and therefore a spatial gap.
    """
    from shapely.ops import unary_union

    # pass scenes that have no gaps
    sorted_products = []
    track_rejected_inds = []
    pair_dict = {}
    product_df_dict = product_df.to_dict('records')
    # Check for (and remove) duplicate products
    # If multiple pairs in list, cycle through
    # and evaluate temporal connectivity.
    for i in enumerate(product_df_dict[:-1]):
        # Parse the first frame's metadata
        scene_start = i[1]['startTime']
        scene_end = i[1]['stopTime']
        first_frame_ind = i[1]['ind_col']
        first_frame = datetime.datetime.strptime( \
                i[1]['fileID'][17:25], "%Y%m%d")
        # Parse the second frame's metadata
        new_scene_start = product_df_dict[i[0]+1]['startTime']
        new_scene_end = product_df_dict[i[0]+1]['stopTime']
        next_frame_ind = product_df_dict[i[0]+1]['ind_col']
        next_frame = datetime.datetime.strptime( \
                product_df_dict[i[0]+1]['fileID'][17:25], "%Y%m%d")

        # Determine if next product in time is in same orbit AND overlaps
        # AND corresponds to same scene
        # If it is within same orbit cycle, try to append scene.
        # This accounts for day change.
        if abs(new_scene_end-scene_end) <= \
                datetime.timedelta(minutes=100) \
                and abs(next_frame-first_frame) <= \
                datetime.timedelta(days=1):
            # Don't export product if it is already tracked
            # as a rejected scene
            if first_frame_ind in track_rejected_inds or \
                    next_frame_ind in track_rejected_inds:
                track_rejected_inds.append(first_frame_ind)
                track_rejected_inds.append(next_frame_ind)

            # Only pass scene if it temporally overlaps with reference scene
            elif ((scene_end <= new_scene_start) and \
                    (new_scene_end <= scene_start)) or \
                    ((scene_end >= new_scene_start) and \
                    (new_scene_end >= scene_start)):
                # Check if dictionary for scene already exists,
                # and if it does then append values
                try:
                    dict_ind = sorted_products.index(next(item for item \
                            in sorted_products if i[1][iter_id] \
                            in item[iter_id]))
                    sorted_products[dict_ind] = {key: np.hstack([value] + \
                         [product_df_dict[i[0]+1][key]]).tolist() \
                         for key, value in sorted_products[dict_ind].items()}
                # Match corresponding to scene NOT found,
                # so initialize dictionary for new scene
                except:
                    sorted_products.extend([dict(zip(i[1].keys(), \
                            [list(a) for a in zip(i[1].values(), \
                            product_df_dict[i[0]+1].values())]))])

            # Else if scene doesn't overlap, this means there is a gap.
            # Reject date from product list,
            # and keep track of all failed dates
            else:
                track_rejected_inds.append(first_frame_ind)
                track_rejected_inds.append(next_frame_ind)
        # Products correspond to different dates,
        # So pass both as separate scenes.
        else:
            # Check if dictionary for corresponding scene already exists.
            if [item for item in sorted_products if i[1][iter_id] in \
                    item[iter_id]]==[] and i[1]['ind_col'] not in \
                    track_rejected_inds:
                sorted_products.extend([dict(zip(i[1].keys(), \
                        [list(a) for a in zip(i[1].values())]))])
            # Initiate new scene
            if [item for item in sorted_products if \
                    product_df_dict[i[0]+1][iter_id] in item[iter_id]]==[] \
                    and next_frame_ind not in track_rejected_inds:
                sorted_products.extend([dict(zip( \
                        product_df_dict[i[0]+1].keys(), \
                        [list(a) for a in \
                        zip(product_df_dict[i[0]+1].values())]))])
            if first_frame_ind in track_rejected_inds:
                track_rejected_inds.append(first_frame_ind)
            if next_frame_ind in track_rejected_inds:
                track_rejected_inds.append(next_frame_ind)

    # Remove duplicate dates
    track_rejected_inds = list(set(track_rejected_inds))
    if len(track_rejected_inds) > 0:
        print("{}/{} scenes rejected as stitched IFGs have gaps".format( \
             len(track_rejected_inds), len(product_df)))
        # Provide report of which files were kept vs. which were not.
        print("Specifically, the following scenes were rejected:")
        for item in product_df_dict:
            if item['ind_col'] in track_rejected_inds:
                print(item['fileID'])
    else:
        print("All {} scenes are spatially continuous.".format( \
             len(sorted_products)))

    # pass scenes that have no gaps
    sorted_products = [item for item in sorted_products \
            if not (any(x in track_rejected_inds for x in item['ind_col']))]

    # Report dictionaries for all valid products
    if sorted_products == []: #Check if pairs were successfully selected
        raise Exception('No scenes meet spatial criteria'
                        'due to gaps and/or invalid input.'
                        'Nothing to export.')

    # Combine polygons
    for i in enumerate(sorted_products):
        sorted_products[i[0]]['geometry'] = unary_union(i[1]['geometry'])

    # combine and record scenes with gaps
    track_kept_inds = pd.DataFrame(sorted_products)['ind_col'].to_list()
    track_kept_inds = [item for sublist in track_kept_inds for item in sublist]
    temp_gap_scenes_dict = [item for item in product_df_dict \
            if not item['ind_col'] in track_kept_inds]
    gap_scenes_dict = []
    for i in enumerate(temp_gap_scenes_dict[:-1]):
        # Parse the first frame's metadata
        first_frame_ind = i[1]['ind_col']
        first_frame = datetime.datetime.strptime( \
                i[1]['fileID'][17:25], "%Y%m%d")
        # Parse the second frame's metadata
        next_frame_ind = temp_gap_scenes_dict[i[0]+1]['ind_col']
        next_frame = datetime.datetime.strptime( \
                temp_gap_scenes_dict[i[0]+1]['fileID'][17:25], "%Y%m%d")
        # Determine if next product in time is in same orbit
        # If it is within same orbit cycle, try to append scene.
        # This accounts for day change.
        if abs(next_frame-first_frame) <= \
            datetime.timedelta(days=1):
            # Check if dictionary for scene already exists,
            # and if it does then append values
            try:
                dict_ind = gap_scenes_dict.index(next(item for item \
                        in gap_scenes_dict if i[1][iter_id] \
                        in item[iter_id]))
                gap_scenes_dict[dict_ind] = {key: np.hstack([value] + \
                        [temp_gap_scenes_dict[i[0]+1][key]]).tolist() \
                        for key, value in gap_scenes_dict[dict_ind].items()}
            # Match corresponding to scene NOT found,
            # so initialize dictionary for new scene
            except:
                gap_scenes_dict.extend([dict(zip(i[1].keys(), \
                        [list(a) for a in zip(i[1].values(), \
                        temp_gap_scenes_dict[i[0]+1].values())]))])
        # Products correspond to different dates,
        # So pass both as separate scenes.
        else:
            # Check if dictionary for corresponding scene already exists.
            if [item for item in gap_scenes_dict if i[1][iter_id] in \
                    item[iter_id]]==[]:
                gap_scenes_dict.extend([dict(zip(i[1].keys(), \
                        [list(a) for a in zip(i[1].values())]))])
            # Initiate new scene
            if [item for item in gap_scenes_dict if \
                    temp_gap_scenes_dict[i[0]+1][iter_id] in item[iter_id]]==[]:
                gap_scenes_dict.extend([dict(zip( \
                        temp_gap_scenes_dict[i[0]+1].keys(), \
                        [list(a) for a in \
                        zip(temp_gap_scenes_dict[i[0]+1].values())]))])

    # there may be some extra missed pairs with gaps
    if gap_scenes_dict != []:
        extra_track_rejected_inds = pd.DataFrame(gap_scenes_dict)['ind_col'].to_list()
        extra_track_rejected_inds = [item for sublist in extra_track_rejected_inds for item in sublist]
        track_rejected_inds.extend(extra_track_rejected_inds)

    return sorted_products, track_rejected_inds, gap_scenes_dict

# %%
def minimum_overlap_query(tiles,
        aoi,
        azimuth_mismatch=0.01,
        iter_id='fileID'):
    """
    Master function managing checks for SAR scene spatiotemporal contiguity
    and filtering out scenes based off of user-defined spatial coverage threshold
    """
    # initiate dataframe
    tiles = tiles.sort_values(['startTime'])
    updated_tiles = tiles.copy()

    # Drop scenes that don't intersect with AOI at all
    orig_len = updated_tiles.shape[0]
    for index, row in tiles.iterrows():
        intersection_area = aoi.intersection(row['geometry'])
        overlap_area = shapefile_area(intersection_area)
        aoi_area = shapefile_area(aoi)
        percentage_coverage = (overlap_area/aoi_area)*100
        if percentage_coverage == 0:
            drop_ind = updated_tiles[updated_tiles['fileID'] == row['fileID']].index
            updated_tiles = updated_tiles.drop(index=drop_ind)
    updated_tiles = updated_tiles.reset_index(drop=True)
    print("{}/{} scenes rejected for not intersecting with the AOI".format( \
          orig_len-updated_tiles.shape[0], orig_len))

    # group IFGs spatiotemporally
    updated_tiles['ind_col'] = range(0, len(updated_tiles))
    updated_tiles_dict, dropped_indices, gap_scenes_dict = continuous_time(updated_tiles, iter_id)
    for i in dropped_indices:
        drop_ind = updated_tiles.index[updated_tiles['ind_col'] == i]
        updated_tiles.drop(drop_ind, inplace=True)
    updated_tiles = updated_tiles.reset_index(drop=True)
    
    # Kick out scenes that do not meet user-defined spatial threshold
    aoi_area = shapefile_area(aoi)
    orig_len = updated_tiles.shape[0]
    track_rejected_inds = []
    minimum_overlap_threshold = aoi_area - (250 * azimuth_mismatch)
    print("")
    print("AOI coverage: {}".format(aoi_area))
    print("Allowable area of miscoverage: {}".format(250 * azimuth_mismatch))
    print("minimum_overlap_threshold: {}".format(minimum_overlap_threshold))
    print("")
    if minimum_overlap_threshold < 0:
        raise Exception('WARNING: user-defined mismatch of {}km\u00b2 too large relative to specified AOI'.format(azimuth_mismatch))
    for i in enumerate(updated_tiles_dict):
        intersection_area = aoi.intersection(i[1]['geometry'])
        overlap_area = shapefile_area(intersection_area)
        # Kick out scenes below specified overlap threshold
        if minimum_overlap_threshold > overlap_area:
            for iter_ind in enumerate(i[1]['ind_col']):
                track_rejected_inds.append(iter_ind[1])
                print("Rejected scene {} has only {}km\u00b2 overlap with AOI".format( \
                    i[1]['fileID'][iter_ind[0]], int(overlap_area)))
                drop_ind = updated_tiles[updated_tiles['ind_col'] == iter_ind[1]].index
                updated_tiles = updated_tiles.drop(index=drop_ind)
    updated_tiles = updated_tiles.reset_index(drop=True)
    print("{}/{} scenes rejected for not meeting defined spatial criteria".format( \
          orig_len-updated_tiles.shape[0], orig_len))

    # record rejected scenes separately
    rejected_scenes_dict = [item for item in updated_tiles_dict \
            if (any(x in track_rejected_inds for x in item['ind_col']))]
    # pass scenes that are not tracked as rejected
    updated_tiles_dict = [item for item in updated_tiles_dict \
            if not (any(x in track_rejected_inds for x in item['ind_col']))]

    return updated_tiles, pd.DataFrame(updated_tiles_dict), pd.DataFrame(gap_scenes_dict), pd.DataFrame(rejected_scenes_dict)

# %%
def pair_spatial_check(tiles,
        aoi,
        azimuth_mismatch=0.01,
        iter_id='fileID'):
    """
    Santity check function to confirm selected pairs meet user-defined spatial coverage threshold
    """
    tiles['ind_col'] = range(0, len(tiles))
    tiles = tiles.drop(columns=['reference', 'secondary'])
    tiles_dict, dropped_pairs, gap_scenes_dict = continuous_time(tiles, iter_id='ind_col')

    # Kick out scenes that do not meet user-defined spatial threshold
    aoi_area = shapefile_area(aoi)
    orig_len = tiles.shape[0]
    minimum_overlap_threshold = aoi_area - (250 * azimuth_mismatch)
    if minimum_overlap_threshold < 0:
        raise Exception('WARNING: user-defined mismatch of {}km\u00b2 too large relative to specified AOI'.format(azimuth_mismatch))
    for i in enumerate(tiles_dict):
        intersection_area = aoi.intersection(i[1]['geometry'])
        overlap_area = shapefile_area(intersection_area)
        # Kick out scenes below specified overlap threshold
        if minimum_overlap_threshold > overlap_area:
            for iter_ind in enumerate(i[1]['ind_col']):
                print("Rejected pair {} has only {}km\u00b2 overlap with AOI {}ID {}Ind".format( \
                      i[1]['reference_date'][iter_ind[0]].replace('-', '') + '_' + \
                      i[1]['secondary_date'][iter_ind[0]].replace('-', ''), \
                      overlap_area, iter_ind[1], i[0]))
                drop_ind = tiles[tiles['ind_col'] == iter_ind[1]].index
                tiles = tiles.drop(index=drop_ind)
    tiles = tiles.reset_index(drop=True)
    print("{}/{} scenes rejected for not meeting defined spatial criteria".format( \
          orig_len-tiles.shape[0], orig_len))

    return pd.DataFrame(tiles_dict)

# %%
df_aoi = gpd.read_file(aoi_shapefile)
aoi = df_aoi.geometry.unary_union
aoi

# %% [markdown]
# Currently, there is a lot of data in each of the rows above. We really only need the AOI `geometry` and the `path_number`.

# %%
path_numbers = df_aoi.path_number.unique().tolist()
# Out:
# [165]

# %% [markdown]
# # Generate a stack
#
# Using all the tiles that are needed to cover the AOI we make a geometric query based on the frame. We now include only the path we are interested in.

# %%
path_dict = {}
path_dict['pathNumber'] = str(path_numbers[0])
aoi_geometry = pd.DataFrame([path_dict])
aoi_geometry = gpd.GeoDataFrame(aoi_geometry, geometry=[shape(aoi)], crs=CRS.from_epsg(4326))
aoi_geometry['pathNumber'] = aoi_geometry['pathNumber'].astype(int)

# %%
df_stack = get_s1_stack_by_dataframe(aoi_geometry,
                                     path_numbers=path_numbers)
# Out:
# Downloading stack for 1 tiles: 100%|██████████| 1/1 [00:12<00:00, 12.62s/it]

# %%
f'We have {df_stack.shape[0]} frames in our stack'
# Out:
# 'We have 1755 frames in our stack'

# %%
fig, ax = plt.subplots()

df_stack.plot(ax=ax, alpha=.5, color='green', label='Frames interesecting tile')
df_aoi.exterior.plot(color='black', ax=ax, label='AOI')
plt.legend()

# %% [markdown]
# Note, we now see the frames cover the entire AOI as we expect.

# %% [markdown]
# First remove all scenes that do not produce spatiotemporally contiguous pairs and not meet specified intersection threshold

# %%
df_stack, df_stack_dict, gap_scenes_dict, rejected_scenes_dict = minimum_overlap_query(df_stack, aoi, azimuth_mismatch=azimuth_mismatch)
# Out:
# 0/1755 scenes rejected for not intersecting with the AOI
# 22/1755 scenes rejected as stitched IFGs have gaps
# Specifically, the following scenes were rejected:
# S1A_IW_SLC__1SSV_20141122T003129_20141122T003156_003387_003F15_8A31-SLC
# S1A_IW_SLC__1SSV_20141122T003219_20141122T003247_003387_003F15_2F6C-SLC
# S1A_IW_SLC__1SSV_20141122T003245_20141122T003312_003387_003F15_8318-SLC
# S1A_IW_SLC__1SSV_20141122T003310_20141122T003337_003387_003F15_9663-SLC
# S1A_IW_SLC__1SSV_20141122T003334_20141122T003401_003387_003F15_0B90-SLC
# S1A_IW_SLC__1SSV_20141122T003359_20141122T003426_003387_003F15_1D75-SLC
# S1A_IW_SLC__1SSV_20150322T003127_20150322T003154_005137_006796_6B07-SLC
# S1A_IW_SLC__1SSV_20150322T003307_20150322T003334_005137_006796_377B-SLC
# S1A_IW_SLC__1SSV_20150322T003332_20150322T003359_005137_006796_E691-SLC
# S1A_IW_SLC__1SSV_20150322T003357_20150322T003424_005137_006796_79A0-SLC
# S1A_IW_SLC__1SSV_20150322T003422_20150322T003449_005137_006796_E763-SLC
# S1A_IW_SLC__1SSV_20150322T003447_20150322T003506_005137_006796_6479-SLC
# S1A_IW_SLC__1SSV_20150602T003156_20150602T003223_006187_008104_2925-SLC
# S1A_IW_SLC__1SSV_20150602T003245_20150602T003313_006187_008104_61C0-SLC
# S1A_IW_SLC__1SSV_20150602T003311_20150602T003338_006187_008104_80DC-SLC
# S1A_IW_SLC__1SSV_20150602T003336_20150602T003403_006187_008104_806B-SLC
# S1A_IW_SLC__1SSV_20150602T003401_20150602T003428_006187_008104_6A4B-SLC
# S1A_IW_SLC__1SSV_20150602T003425_20150602T003452_006187_008104_BB8A-SLC
# S1A_IW_SLC__1SSV_20150602T003450_20150602T003518_006187_008104_967E-SLC
# S1B_IW_SLC__1SDV_20210320T003211_20210320T003238_026091_031CF9_06E8-SLC
# S1B_IW_SLC__1SDV_20210320T003327_20210320T003354_026091_031CF9_EBE6-SLC
# S1B_IW_SLC__1SDV_20210320T003352_20210320T003411_026091_031CF9_E424-SLC
#
# AOI coverage: 402064.6758297722
# Allowable area of miscoverage: 12500
# minimum_overlap_threshold: 389564.6758297722
#
# Rejected scene S1A_IW_SLC__1SSV_20141110T003455_20141110T003525_003212_003B4D_AB18-SLC has only 16806km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SSV_20141204T003455_20141204T003524_003562_004338_CEF1-SLC has only 16804km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SSV_20141228T003454_20141228T003524_003912_004B2F_25D2-SLC has only 16798km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SSV_20150121T003453_20150121T003523_004262_0052EB_E11E-SLC has only 16803km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SSV_20150214T003452_20150214T003522_004612_005AED_BB4C-SLC has only 16773km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20150310T003453_20150310T003523_004962_00635E_4B08-SLC has only 16813km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SSV_20150403T003453_20150403T003523_005312_006B9E_7B4C-SLC has only 16817km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SSV_20150427T003454_20150427T003524_005662_007435_C01D-SLC has only 16787km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SSV_20150509T003129_20150509T003156_005837_007833_FDD6-SLC has only 368118km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SSV_20150509T003154_20150509T003221_005837_007833_1594-SLC has only 368118km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SSV_20150509T003219_20150509T003246_005837_007833_AA8C-SLC has only 368118km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SSV_20150509T003244_20150509T003312_005837_007833_3CAB-SLC has only 368118km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SSV_20150509T003309_20150509T003336_005837_007833_FDC6-SLC has only 368118km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SSV_20150509T003334_20150509T003401_005837_007833_CA01-SLC has only 368118km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SSV_20150509T003359_20150509T003426_005837_007833_329B-SLC has only 368118km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SSV_20150509T003424_20150509T003451_005837_007833_E6F8-SLC has only 368118km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SSV_20150509T003449_20150509T003516_005837_007833_9A3A-SLC has only 368118km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SSV_20150521T003434_20150521T003503_006012_007C09_6474-SLC has only 54111km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SSV_20150521T003501_20150521T003528_006012_007C09_0B4F-SLC has only 54111km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SSV_20150614T003435_20150614T003505_006362_008616_02E6-SLC has only 54091km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SSV_20150614T003503_20150614T003530_006362_008616_16F4-SLC has only 54091km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SSV_20150708T003435_20150708T003505_006712_008FBB_4891-SLC has only 54111km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SSV_20150708T003503_20150708T003530_006712_008FBB_9BA4-SLC has only 54111km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SSV_20150825T003501_20150825T003530_007412_00A338_C376-SLC has only 16817km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SSV_20150918T003501_20150918T003531_007762_00ACAC_2000-SLC has only 16798km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SSV_20160714T003114_20160714T003141_012137_012CE2_7A95-SLC has only 171592km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SSV_20160714T003139_20160714T003206_012137_012CE2_0D93-SLC has only 171592km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SSV_20160714T003204_20160714T003231_012137_012CE2_ED3B-SLC has only 171592km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SSV_20160714T003228_20160714T003300_012137_012CE2_BB22-SLC has only 171592km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20161006T003503_20161006T003533_013362_015508_4850-SLC has only 26143km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20161018T003503_20161018T003533_013537_015AA2_F874-SLC has only 26160km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20161030T003503_20161030T003533_013712_015FF9_13AE-SLC has only 26159km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20161111T003503_20161111T003532_013887_01658E_1F18-SLC has only 26140km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20161123T003502_20161123T003532_014062_016AD6_51A0-SLC has only 26151km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20161205T003502_20161205T003532_014237_017055_B7D6-SLC has only 26126km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20161217T003502_20161217T003531_014412_0175D7_91E4-SLC has only 26126km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20161229T003501_20161229T003531_014587_017B51_C2DB-SLC has only 26133km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20170110T003500_20170110T003530_014762_018091_123D-SLC has only 26149km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20170122T003459_20170122T003529_014937_018614_DDF7-SLC has only 26152km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20170203T003459_20170203T003529_015112_018B56_2D8A-SLC has only 26123km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20170329T003014_20170329T003042_004916_00897B_87A1-SLC has only 7669km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20170410T003014_20170410T003042_005091_008E88_823A-SLC has only 7659km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20170422T003015_20170422T003043_005266_009396_6C7A-SLC has only 7667km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20170516T003016_20170516T003044_005616_009D5F_A2DB-SLC has only 7649km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20170528T003016_20170528T003044_005791_00A26E_ABE0-SLC has only 7632km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20170609T003017_20170609T003045_005966_00A781_9208-SLC has only 7627km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20170621T003018_20170621T003046_006141_00AC9F_5710-SLC has only 7615km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20170703T003019_20170703T003047_006316_00B1B0_E07D-SLC has only 7642km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20170709T003518_20170709T003548_017387_01D0AC_1672-SLC has only 2910km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20170715T003020_20170715T003047_006491_00B6A0_A89C-SLC has only 7644km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20170727T003020_20170727T003048_006666_00BB9E_3A62-SLC has only 7645km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20170808T003021_20170808T003049_006841_00C0AA_2002-SLC has only 7652km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20170820T003021_20170820T003049_007016_00C5C6_D124-SLC has only 7624km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20170901T003022_20170901T003050_007191_00CAD2_807A-SLC has only 7657km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20170913T003022_20170913T003050_007366_00CFF7_E5C0-SLC has only 7668km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20170925T003023_20170925T003051_007541_00D503_7CFC-SLC has only 7660km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20171007T003023_20171007T003051_007716_00DA0B_7EC7-SLC has only 7670km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20171019T003023_20171019T003051_007891_00DF03_11CC-SLC has only 7674km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20171112T003023_20171112T003051_008241_00E932_E586-SLC has only 7661km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20171124T003023_20171124T003051_008416_00EE7C_C9E1-SLC has only 7650km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20171206T003022_20171206T003050_008591_00F40B_B482-SLC has only 7653km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20171218T003022_20171218T003050_008766_00F99E_3971-SLC has only 7651km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20171230T003021_20171230T003049_008941_00FF37_BBE5-SLC has only 7651km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20180111T003021_20180111T003049_009116_0104F0_51CE-SLC has only 7656km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20180123T003020_20180123T003048_009291_010AA4_DD49-SLC has only 7648km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20180204T003020_20180204T003048_009466_011061_86E0-SLC has only 7658km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20180216T003020_20180216T003048_009641_011626_BAF9-SLC has only 7665km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20180228T003020_20180228T003048_009816_011BF0_BB9E-SLC has only 7661km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20180312T003020_20180312T003048_009991_0121CF_783F-SLC has only 7665km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20180324T003020_20180324T003048_010166_01277B_81C6-SLC has only 7652km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20180405T003021_20180405T003049_010341_012D2E_5900-SLC has only 7656km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20180417T003021_20180417T003049_010516_0132C3_6E8C-SLC has only 7652km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20180429T003021_20180429T003049_010691_01385F_486C-SLC has only 7643km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20180511T003022_20180511T003050_010866_013E05_29CD-SLC has only 7644km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20180523T003023_20180523T003051_011041_0143B3_097B-SLC has only 7645km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20180604T003023_20180604T003051_011216_01495F_C6ED-SLC has only 7637km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20180628T003025_20180628T003053_011566_01542A_F0A8-SLC has only 7640km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20180710T003026_20180710T003054_011741_015999_C74F-SLC has only 7658km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20180722T003027_20180722T003055_011916_015EF3_AA46-SLC has only 7647km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20180803T003027_20180803T003055_012091_016438_4DA9-SLC has only 7651km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20180815T003028_20180815T003056_012266_0169A1_AFC2-SLC has only 7652km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20190301T003129_20190301T003158_026137_02EAA8_6510-SLC has only 214299km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20190301T003156_20190301T003224_026137_02EAA8_F63C-SLC has only 214299km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20190301T003222_20190301T003249_026137_02EAA8_6ED3-SLC has only 214299km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20190301T003247_20190301T003314_026137_02EAA8_8282-SLC has only 214299km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20190301T003312_20190301T003338_026137_02EAA8_2A50-SLC has only 214299km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20190313T003129_20190313T003158_026312_02F103_9AC8-SLC has only 214325km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20190313T003156_20190313T003224_026312_02F103_8C4C-SLC has only 214325km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20190313T003222_20190313T003249_026312_02F103_5F41-SLC has only 214325km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20190313T003247_20190313T003314_026312_02F103_DCCE-SLC has only 214325km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20190313T003311_20190313T003338_026312_02F103_10B5-SLC has only 214325km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20190325T003129_20190325T003159_026487_02F77D_375F-SLC has only 214241km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20190325T003156_20190325T003224_026487_02F77D_019F-SLC has only 214241km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20190325T003222_20190325T003249_026487_02F77D_C8E7-SLC has only 214241km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20190325T003247_20190325T003314_026487_02F77D_B5DA-SLC has only 214241km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20190325T003312_20190325T003338_026487_02F77D_DA08-SLC has only 214241km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20190406T003129_20190406T003159_026662_02FDF4_5F58-SLC has only 214152km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20190406T003157_20190406T003224_026662_02FDF4_FCA7-SLC has only 214152km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20190406T003222_20190406T003249_026662_02FDF4_22B8-SLC has only 214152km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20190406T003247_20190406T003314_026662_02FDF4_0BDB-SLC has only 214152km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20190406T003312_20190406T003338_026662_02FDF4_8B61-SLC has only 214152km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20190430T003130_20190430T003200_027012_030AA8_1530-SLC has only 214193km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20190430T003158_20190430T003226_027012_030AA8_2B8C-SLC has only 214193km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20190430T003223_20190430T003250_027012_030AA8_88A1-SLC has only 214193km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20190430T003248_20190430T003315_027012_030AA8_7DB4-SLC has only 214193km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20190430T003313_20190430T003339_027012_030AA8_E33B-SLC has only 214193km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20190512T003130_20190512T003200_027187_03109D_D125-SLC has only 44308km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20190524T003131_20190524T003201_027362_031617_F02B-SLC has only 44288km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20190605T003132_20190605T003150_027537_031B83_F7C7-SLC has only 25940km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20190816T003136_20190816T003206_028587_033BC8_C43B-SLC has only 214399km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20190816T003204_20190816T003232_028587_033BC8_7631-SLC has only 214399km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20190816T003230_20190816T003256_028587_033BC8_5026-SLC has only 214399km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20190816T003254_20190816T003321_028587_033BC8_27E8-SLC has only 214399km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20190816T003319_20190816T003345_028587_033BC8_5BDC-SLC has only 214399km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20190828T003137_20190828T003206_028762_0341E2_0540-SLC has only 214470km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20190828T003204_20190828T003232_028762_0341E2_79C2-SLC has only 214470km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20190828T003230_20190828T003257_028762_0341E2_BA0A-SLC has only 214470km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20190828T003255_20190828T003322_028762_0341E2_47E5-SLC has only 214470km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20190828T003320_20190828T003346_028762_0341E2_4395-SLC has only 214470km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20190909T003137_20190909T003207_028937_0347F6_619D-SLC has only 173344km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20190909T003205_20190909T003233_028937_0347F6_1DD3-SLC has only 173344km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20190909T003231_20190909T003258_028937_0347F6_0072-SLC has only 173344km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20190909T003255_20190909T003322_028937_0347F6_C991-SLC has only 173344km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20190921T003138_20190921T003208_029112_034DFD_E72B-SLC has only 214517km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20190921T003205_20190921T003233_029112_034DFD_9BC6-SLC has only 214517km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20190921T003231_20190921T003258_029112_034DFD_BA16-SLC has only 214517km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20190921T003256_20190921T003323_029112_034DFD_80F1-SLC has only 214517km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20190921T003321_20190921T003347_029112_034DFD_89A1-SLC has only 214517km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20191003T003138_20191003T003208_029287_0353FF_3C52-SLC has only 173316km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20191003T003206_20191003T003234_029287_0353FF_784E-SLC has only 173316km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20191003T003232_20191003T003259_029287_0353FF_5AB1-SLC has only 173316km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20191003T003256_20191003T003323_029287_0353FF_7657-SLC has only 173316km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20191009T003420_20191009T003450_018391_022A53_C424-SLC has only 58717km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20191009T003448_20191009T003516_018391_022A53_C506-SLC has only 58717km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20191015T003138_20191015T003208_029462_035A10_D88C-SLC has only 214534km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20191015T003206_20191015T003234_029462_035A10_378B-SLC has only 214534km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20191015T003231_20191015T003258_029462_035A10_F509-SLC has only 214534km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20191015T003256_20191015T003323_029462_035A10_DB38-SLC has only 214534km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20191015T003321_20191015T003347_029462_035A10_C8A1-SLC has only 214534km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20191021T003421_20191021T003450_018566_022FB3_348C-SLC has only 58728km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20191021T003448_20191021T003516_018566_022FB3_F41F-SLC has only 58728km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20191102T003420_20191102T003450_018741_023531_52C1-SLC has only 58724km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20191102T003448_20191102T003516_018741_023531_E4F1-SLC has only 58724km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20191114T003420_20191114T003450_018916_023AD7_0419-SLC has only 58735km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20191114T003448_20191114T003516_018916_023AD7_394B-SLC has only 58735km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20191126T003420_20191126T003450_019091_024078_5550-SLC has only 58734km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20191126T003448_20191126T003516_019091_024078_F768-SLC has only 58734km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20191208T003420_20191208T003450_019266_024600_F5EC-SLC has only 58731km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20191208T003447_20191208T003515_019266_024600_2D19-SLC has only 58731km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20191220T003419_20191220T003449_019441_024B95_EB1A-SLC has only 58728km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20191220T003447_20191220T003515_019441_024B95_B89F-SLC has only 58728km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20191226T003430_20191226T003500_030512_037E77_732F-SLC has only 110013km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20191226T003458_20191226T003526_030512_037E77_B968-SLC has only 110013km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20191226T003524_20191226T003551_030512_037E77_2663-SLC has only 110013km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20200101T003419_20200101T003448_019616_02512D_6BEF-SLC has only 58735km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20200101T003446_20200101T003514_019616_02512D_6DFB-SLC has only 58735km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20200107T003430_20200107T003500_030687_038480_5FFA-SLC has only 109998km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20200107T003458_20200107T003525_030687_038480_FA09-SLC has only 109998km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20200107T003523_20200107T003550_030687_038480_6F01-SLC has only 109998km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20200113T003418_20200113T003448_019791_0256B5_7434-SLC has only 58742km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20200113T003446_20200113T003514_019791_0256B5_8D0A-SLC has only 58742km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20200119T003429_20200119T003459_030862_038AA2_EDA8-SLC has only 109986km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20200119T003457_20200119T003525_030862_038AA2_C224-SLC has only 109986km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20200119T003523_20200119T003550_030862_038AA2_9248-SLC has only 109986km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20200131T003429_20200131T003459_031037_0390C4_E202-SLC has only 110008km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20200131T003457_20200131T003524_031037_0390C4_2333-SLC has only 110008km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20200131T003522_20200131T003549_031037_0390C4_7FC9-SLC has only 110008km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20200212T003429_20200212T003458_031212_0396DD_CB7E-SLC has only 110002km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20200212T003456_20200212T003524_031212_0396DD_9A8A-SLC has only 110002km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20200212T003522_20200212T003549_031212_0396DD_54E5-SLC has only 110002km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20200224T003428_20200224T003458_031387_039CE4_DE8C-SLC has only 110014km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20200224T003456_20200224T003524_031387_039CE4_16A6-SLC has only 110014km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20200224T003522_20200224T003549_031387_039CE4_8530-SLC has only 110014km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20200307T003429_20200307T003458_031562_03A2EE_FD2B-SLC has only 110010km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20200307T003456_20200307T003524_031562_03A2EE_13EE-SLC has only 110010km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20200307T003522_20200307T003549_031562_03A2EE_0B0D-SLC has only 110010km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20200319T003432_20200319T003501_031737_03A905_F393-SLC has only 105336km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20200319T003459_20200319T003527_031737_03A905_E87A-SLC has only 105336km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20200319T003525_20200319T003552_031737_03A905_DC79-SLC has only 105336km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20200331T003434_20200331T003504_031912_03AF2C_D444-SLC has only 100754km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20200331T003502_20200331T003530_031912_03AF2C_52ED-SLC has only 100754km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20200331T003528_20200331T003555_031912_03AF2C_3819-SLC has only 100754km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20200412T003435_20200412T003505_032087_03B557_1B5E-SLC has only 100743km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20200412T003502_20200412T003530_032087_03B557_2E0E-SLC has only 100743km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20200412T003528_20200412T003555_032087_03B557_0AB5-SLC has only 100743km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20200424T003435_20200424T003505_032262_03BB7A_C97E-SLC has only 100758km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20200424T003503_20200424T003531_032262_03BB7A_0222-SLC has only 100758km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20200424T003529_20200424T003556_032262_03BB7A_ED83-SLC has only 100758km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20200506T003436_20200506T003455_032437_03C1A6_5AB5-SLC has only 31598km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20200512T003030_20200512T003100_021541_028E5E_3A33-SLC has only 312245km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20200512T003058_20200512T003126_021541_028E5E_5C02-SLC has only 312245km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20200512T003123_20200512T003150_021541_028E5E_9BF5-SLC has only 312245km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20200512T003148_20200512T003215_021541_028E5E_85BE-SLC has only 312245km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20200512T003213_20200512T003240_021541_028E5E_3E69-SLC has only 312245km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20200512T003238_20200512T003305_021541_028E5E_23C7-SLC has only 312245km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20200512T003303_20200512T003331_021541_028E5E_56FB-SLC has only 312245km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20200512T003328_20200512T003402_021541_028E5E_E927-SLC has only 312245km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20200518T003437_20200518T003506_032612_03C6FC_E560-SLC has only 100766km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20200518T003504_20200518T003532_032612_03C6FC_0F98-SLC has only 100766km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20200518T003530_20200518T003557_032612_03C6FC_ABA4-SLC has only 100766km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20200524T003031_20200524T003101_021716_029381_FC96-SLC has only 312096km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20200524T003058_20200524T003126_021716_029381_3976-SLC has only 312096km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20200524T003124_20200524T003151_021716_029381_12FE-SLC has only 312096km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20200524T003149_20200524T003216_021716_029381_F140-SLC has only 312096km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20200524T003214_20200524T003241_021716_029381_48E9-SLC has only 312096km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20200524T003239_20200524T003306_021716_029381_3992-SLC has only 312096km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20200524T003304_20200524T003331_021716_029381_4175-SLC has only 312096km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20200524T003329_20200524T003403_021716_029381_1D1C-SLC has only 312096km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20200530T003437_20200530T003507_032787_03CC42_6EEB-SLC has only 100761km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20200530T003505_20200530T003533_032787_03CC42_CA72-SLC has only 100761km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20200530T003531_20200530T003558_032787_03CC42_B27F-SLC has only 100761km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20200605T003032_20200605T003102_021891_0298C1_1E4E-SLC has only 312005km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20200605T003059_20200605T003127_021891_0298C1_C1DA-SLC has only 312005km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20200605T003125_20200605T003152_021891_0298C1_AAE2-SLC has only 312005km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20200605T003150_20200605T003217_021891_0298C1_61D7-SLC has only 312005km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20200605T003215_20200605T003242_021891_0298C1_50D2-SLC has only 312005km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20200605T003240_20200605T003307_021891_0298C1_11A9-SLC has only 312005km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20200605T003304_20200605T003332_021891_0298C1_999C-SLC has only 312005km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20200605T003330_20200605T003404_021891_0298C1_825A-SLC has only 312005km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20200611T003438_20200611T003508_032962_03D16E_C461-SLC has only 100770km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20200611T003506_20200611T003533_032962_03D16E_49CC-SLC has only 100770km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20200611T003531_20200611T003558_032962_03D16E_CFBB-SLC has only 100770km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20200617T003032_20200617T003102_022066_029E0C_CAC6-SLC has only 312039km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20200617T003100_20200617T003128_022066_029E0C_247B-SLC has only 312039km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20200617T003126_20200617T003153_022066_029E0C_DFC3-SLC has only 312039km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20200617T003150_20200617T003217_022066_029E0C_9D8F-SLC has only 312039km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20200617T003215_20200617T003242_022066_029E0C_951B-SLC has only 312039km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20200617T003240_20200617T003307_022066_029E0C_7CAD-SLC has only 312039km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20200617T003305_20200617T003333_022066_029E0C_5C25-SLC has only 312039km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20200617T003331_20200617T003404_022066_029E0C_FB44-SLC has only 312039km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20200623T003439_20200623T003509_033137_03D6C0_B516-SLC has only 100787km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20200623T003506_20200623T003534_033137_03D6C0_1CC1-SLC has only 100787km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20200623T003532_20200623T003559_033137_03D6C0_EA9F-SLC has only 100787km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20200629T003033_20200629T003103_022241_02A365_CC82-SLC has only 312122km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20200629T003101_20200629T003128_022241_02A365_2F68-SLC has only 312122km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20200629T003126_20200629T003153_022241_02A365_F9D7-SLC has only 312122km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20200629T003151_20200629T003218_022241_02A365_EF98-SLC has only 312122km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20200629T003216_20200629T003243_022241_02A365_E781-SLC has only 312122km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20200629T003241_20200629T003308_022241_02A365_FEDE-SLC has only 312122km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20200629T003306_20200629T003334_022241_02A365_A937-SLC has only 312122km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20200629T003331_20200629T003405_022241_02A365_21F0-SLC has only 312122km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20200705T003439_20200705T003509_033312_03DC0E_A90F-SLC has only 100776km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20200705T003507_20200705T003535_033312_03DC0E_BEE6-SLC has only 100776km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20200705T003533_20200705T003600_033312_03DC0E_46C3-SLC has only 100776km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20200711T003034_20200711T003104_022416_02A8B8_E7CA-SLC has only 312099km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20200711T003101_20200711T003129_022416_02A8B8_BACD-SLC has only 312099km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20200711T003127_20200711T003154_022416_02A8B8_5601-SLC has only 312099km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20200711T003152_20200711T003219_022416_02A8B8_C717-SLC has only 312099km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20200711T003217_20200711T003244_022416_02A8B8_800A-SLC has only 312099km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20200711T003242_20200711T003308_022416_02A8B8_D296-SLC has only 312099km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20200711T003306_20200711T003334_022416_02A8B8_433A-SLC has only 312099km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20200711T003332_20200711T003406_022416_02A8B8_0068-SLC has only 312099km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20200717T003440_20200717T003510_033487_03E166_DF32-SLC has only 100764km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20200717T003508_20200717T003535_033487_03E166_BC19-SLC has only 100764km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20200717T003533_20200717T003600_033487_03E166_CE48-SLC has only 100764km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20200723T003034_20200723T003104_022591_02AE09_A1E8-SLC has only 312094km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20200723T003102_20200723T003130_022591_02AE09_28C1-SLC has only 312094km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20200723T003128_20200723T003155_022591_02AE09_F562-SLC has only 312094km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20200723T003152_20200723T003219_022591_02AE09_B1C7-SLC has only 312094km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20200723T003217_20200723T003244_022591_02AE09_D8AE-SLC has only 312094km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20200723T003242_20200723T003309_022591_02AE09_EC97-SLC has only 312094km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20200723T003307_20200723T003335_022591_02AE09_4B49-SLC has only 312094km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20200723T003333_20200723T003406_022591_02AE09_F7C4-SLC has only 312094km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20200729T003441_20200729T003511_033662_03E6C5_0E16-SLC has only 100783km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20200729T003509_20200729T003536_033662_03E6C5_83C5-SLC has only 100783km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20200729T003534_20200729T003601_033662_03E6C5_963C-SLC has only 100783km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20200804T003035_20200804T003105_022766_02B354_CAD6-SLC has only 311973km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20200804T003103_20200804T003131_022766_02B354_70F4-SLC has only 311973km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20200804T003129_20200804T003156_022766_02B354_B149-SLC has only 311973km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20200804T003153_20200804T003220_022766_02B354_5A93-SLC has only 311973km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20200804T003218_20200804T003245_022766_02B354_3843-SLC has only 311973km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20200804T003243_20200804T003310_022766_02B354_62A6-SLC has only 311973km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20200804T003308_20200804T003336_022766_02B354_ADB3-SLC has only 311973km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20200804T003334_20200804T003407_022766_02B354_1B46-SLC has only 311973km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20200810T003442_20200810T003511_033837_03EC6D_88A0-SLC has only 100754km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20200810T003509_20200810T003537_033837_03EC6D_CFEC-SLC has only 100754km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20200810T003535_20200810T003602_033837_03EC6D_908F-SLC has only 100754km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20200816T003036_20200816T003106_022941_02B8BA_7B27-SLC has only 312047km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20200816T003103_20200816T003131_022941_02B8BA_8C8B-SLC has only 312047km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20200816T003129_20200816T003156_022941_02B8BA_B9A4-SLC has only 312047km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20200816T003154_20200816T003221_022941_02B8BA_4DAB-SLC has only 312047km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20200816T003219_20200816T003246_022941_02B8BA_C1F1-SLC has only 312047km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20200816T003244_20200816T003311_022941_02B8BA_C956-SLC has only 312047km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20200816T003309_20200816T003336_022941_02B8BA_16EC-SLC has only 312047km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20200816T003334_20200816T003408_022941_02B8BA_3A60-SLC has only 312047km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20200822T003442_20200822T003512_034012_03F294_368C-SLC has only 100735km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20200822T003510_20200822T003538_034012_03F294_8187-SLC has only 100735km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20200822T003536_20200822T003602_034012_03F294_5742-SLC has only 100735km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20200828T003037_20200828T003107_023116_02BE3D_C118-SLC has only 312039km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20200828T003104_20200828T003132_023116_02BE3D_8BF3-SLC has only 312039km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20200828T003130_20200828T003157_023116_02BE3D_C841-SLC has only 312039km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20200828T003155_20200828T003222_023116_02BE3D_403E-SLC has only 312039km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20200828T003220_20200828T003247_023116_02BE3D_E63C-SLC has only 312039km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20200828T003245_20200828T003311_023116_02BE3D_2831-SLC has only 312039km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20200828T003309_20200828T003337_023116_02BE3D_2FCF-SLC has only 312039km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20200828T003335_20200828T003409_023116_02BE3D_65F6-SLC has only 312039km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20200903T003443_20200903T003513_034187_03F8BE_5DBF-SLC has only 100735km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20200903T003510_20200903T003538_034187_03F8BE_A122-SLC has only 100735km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20200903T003536_20200903T003603_034187_03F8BE_EB01-SLC has only 100735km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20200909T003037_20200909T003107_023291_02C3BC_8CBB-SLC has only 312097km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20200909T003105_20200909T003133_023291_02C3BC_ACE2-SLC has only 312097km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20200909T003130_20200909T003157_023291_02C3BC_0C7D-SLC has only 312097km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20200909T003155_20200909T003222_023291_02C3BC_519F-SLC has only 312097km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20200909T003220_20200909T003247_023291_02C3BC_A612-SLC has only 312097km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20200909T003245_20200909T003312_023291_02C3BC_03FB-SLC has only 312097km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20200909T003310_20200909T003338_023291_02C3BC_6DB5-SLC has only 312097km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20200909T003336_20200909T003409_023291_02C3BC_85C4-SLC has only 312097km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20200915T003443_20200915T003513_034362_03FEE7_99D6-SLC has only 100731km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20200915T003511_20200915T003539_034362_03FEE7_5EA3-SLC has only 100731km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20200915T003537_20200915T003604_034362_03FEE7_DBAD-SLC has only 100731km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20200921T003037_20200921T003107_023466_02C935_612C-SLC has only 312097km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20200921T003105_20200921T003133_023466_02C935_4239-SLC has only 312097km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20200921T003131_20200921T003158_023466_02C935_C1B5-SLC has only 312097km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20200921T003156_20200921T003223_023466_02C935_AB51-SLC has only 312097km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20200921T003220_20200921T003247_023466_02C935_ECCD-SLC has only 312097km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20200921T003245_20200921T003312_023466_02C935_32F2-SLC has only 312097km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20200921T003310_20200921T003338_023466_02C935_71D2-SLC has only 312097km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20200921T003336_20200921T003409_023466_02C935_05DA-SLC has only 312097km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20200927T003444_20200927T003513_034537_04050F_E5ED-SLC has only 100737km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20200927T003511_20200927T003539_034537_04050F_A91C-SLC has only 100737km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20200927T003537_20200927T003604_034537_04050F_F975-SLC has only 100737km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20201003T003100_20201003T003128_023641_02CEAD_B996-SLC has only 321993km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20201003T003126_20201003T003152_023641_02CEAD_BE2E-SLC has only 321993km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20201003T003150_20201003T003217_023641_02CEAD_52FB-SLC has only 321993km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20201003T003215_20201003T003242_023641_02CEAD_ADCB-SLC has only 321993km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20201003T003240_20201003T003307_023641_02CEAD_98C3-SLC has only 321993km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20201003T003305_20201003T003333_023641_02CEAD_C8D9-SLC has only 321993km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20201003T003331_20201003T003358_023641_02CEAD_0EF6-SLC has only 321993km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20201003T003355_20201003T003415_023641_02CEAD_BE2C-SLC has only 321993km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20201009T003444_20201009T003514_034712_040B2C_AFDC-SLC has only 100746km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20201009T003512_20201009T003539_034712_040B2C_0FE9-SLC has only 100746km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20201009T003537_20201009T003604_034712_040B2C_4BD5-SLC has only 100746km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20201015T003100_20201015T003128_023816_02D41F_A2BB-SLC has only 322023km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20201015T003126_20201015T003153_023816_02D41F_4B24-SLC has only 322023km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20201015T003151_20201015T003217_023816_02D41F_D2D1-SLC has only 322023km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20201015T003215_20201015T003242_023816_02D41F_28F6-SLC has only 322023km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20201015T003240_20201015T003307_023816_02D41F_ADA7-SLC has only 322023km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20201015T003305_20201015T003333_023816_02D41F_4602-SLC has only 322023km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20201015T003331_20201015T003358_023816_02D41F_3F31-SLC has only 322023km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20201015T003356_20201015T003415_023816_02D41F_923E-SLC has only 322023km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20201021T003444_20201021T003514_034887_041153_A9A9-SLC has only 100741km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20201021T003511_20201021T003539_034887_041153_2F74-SLC has only 100741km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20201021T003537_20201021T003604_034887_041153_8007-SLC has only 100741km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20201027T003100_20201027T003128_023991_02D99E_1B05-SLC has only 322067km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20201027T003126_20201027T003153_023991_02D99E_0969-SLC has only 322067km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20201027T003151_20201027T003217_023991_02D99E_8FA0-SLC has only 322067km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20201027T003215_20201027T003242_023991_02D99E_B1F1-SLC has only 322067km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20201027T003240_20201027T003307_023991_02D99E_1E8A-SLC has only 322067km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20201027T003305_20201027T003333_023991_02D99E_DA82-SLC has only 322067km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20201027T003331_20201027T003358_023991_02D99E_4D75-SLC has only 322067km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20201027T003356_20201027T003415_023991_02D99E_0B0B-SLC has only 322067km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20201102T003444_20201102T003514_035062_041745_0B8B-SLC has only 100757km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20201102T003511_20201102T003539_035062_041745_7C6D-SLC has only 100757km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20201102T003537_20201102T003604_035062_041745_7EEA-SLC has only 100757km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20201108T003100_20201108T003128_024166_02DF04_AD4B-SLC has only 322005km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20201108T003126_20201108T003153_024166_02DF04_24D4-SLC has only 322005km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20201108T003150_20201108T003217_024166_02DF04_485E-SLC has only 322005km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20201108T003215_20201108T003242_024166_02DF04_272E-SLC has only 322005km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20201108T003240_20201108T003307_024166_02DF04_514A-SLC has only 322005km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20201108T003305_20201108T003333_024166_02DF04_CEBB-SLC has only 322005km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20201108T003331_20201108T003358_024166_02DF04_A428-SLC has only 322005km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20201108T003356_20201108T003415_024166_02DF04_375E-SLC has only 322005km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20201114T003444_20201114T003514_035237_041D68_AF56-SLC has only 100738km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20201114T003511_20201114T003539_035237_041D68_9E4F-SLC has only 100738km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20201114T003537_20201114T003604_035237_041D68_E3A0-SLC has only 100738km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20201120T003100_20201120T003128_024341_02E481_E664-SLC has only 321983km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20201120T003125_20201120T003152_024341_02E481_7082-SLC has only 321983km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20201120T003150_20201120T003217_024341_02E481_0223-SLC has only 321983km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20201120T003215_20201120T003242_024341_02E481_506F-SLC has only 321983km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20201120T003240_20201120T003307_024341_02E481_3D56-SLC has only 321983km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20201120T003305_20201120T003333_024341_02E481_9709-SLC has only 321983km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20201120T003331_20201120T003358_024341_02E481_D1A8-SLC has only 321983km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20201120T003355_20201120T003415_024341_02E481_3305-SLC has only 321983km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20201126T003443_20201126T003513_035412_04236E_85F1-SLC has only 100705km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20201126T003511_20201126T003539_035412_04236E_4AAD-SLC has only 100705km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20201126T003537_20201126T003603_035412_04236E_BDD8-SLC has only 100705km² overlap with AOI
# ...
# Rejected scene S1A_IW_SLC__1SDV_20210829T003542_20210829T003609_039437_04A8B4_D5EC-SLC has only 100757km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20210904T003105_20210904T003133_028541_0367EE_4DAE-SLC has only 321962km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20210904T003130_20210904T003157_028541_0367EE_C9AF-SLC has only 321962km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20210904T003155_20210904T003222_028541_0367EE_0152-SLC has only 321962km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20210904T003220_20210904T003247_028541_0367EE_1899-SLC has only 321962km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20210904T003245_20210904T003312_028541_0367EE_8B0E-SLC has only 321962km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20210904T003310_20210904T003338_028541_0367EE_C97A-SLC has only 321962km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20210904T003336_20210904T003402_028541_0367EE_F6F7-SLC has only 321962km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20210904T003400_20210904T003420_028541_0367EE_CEF6-SLC has only 321962km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20210910T003449_20210910T003519_039612_04AEC7_6EBC-SLC has only 100741km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20210910T003516_20210910T003544_039612_04AEC7_DBD2-SLC has only 100741km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20210910T003542_20210910T003609_039612_04AEC7_64F7-SLC has only 100741km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20210916T003105_20210916T003133_028716_036D4D_8FE4-SLC has only 322033km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20210916T003131_20210916T003158_028716_036D4D_2BDE-SLC has only 322033km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20210916T003156_20210916T003223_028716_036D4D_3EFA-SLC has only 322033km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20210916T003221_20210916T003247_028716_036D4D_EA9C-SLC has only 322033km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20210916T003245_20210916T003312_028716_036D4D_1226-SLC has only 322033km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20210916T003310_20210916T003338_028716_036D4D_EF14-SLC has only 322033km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20210916T003336_20210916T003403_028716_036D4D_0B7B-SLC has only 322033km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20210916T003401_20210916T003420_028716_036D4D_5901-SLC has only 322033km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20210922T003449_20210922T003519_039787_04B4BA_466F-SLC has only 100734km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20210922T003517_20210922T003545_039787_04B4BA_B540-SLC has only 100734km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20210922T003543_20210922T003610_039787_04B4BA_E1FC-SLC has only 100734km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20210928T003106_20210928T003133_028891_0372AB_FC1B-SLC has only 322007km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20210928T003131_20210928T003158_028891_0372AB_CBBD-SLC has only 322007km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20210928T003156_20210928T003223_028891_0372AB_B94B-SLC has only 322007km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20210928T003221_20210928T003248_028891_0372AB_06CE-SLC has only 322007km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20210928T003246_20210928T003313_028891_0372AB_158E-SLC has only 322007km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20210928T003311_20210928T003339_028891_0372AB_2029-SLC has only 322007km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20210928T003336_20210928T003403_028891_0372AB_E947-SLC has only 322007km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20210928T003401_20210928T003421_028891_0372AB_B61A-SLC has only 322007km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20211004T003450_20211004T003519_039962_04BAC8_9B3D-SLC has only 100737km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20211004T003517_20211004T003545_039962_04BAC8_2C62-SLC has only 100737km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20211004T003543_20211004T003610_039962_04BAC8_90FA-SLC has only 100737km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20211010T003106_20211010T003134_029066_0377E9_2C5B-SLC has only 321992km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20211010T003131_20211010T003158_029066_0377E9_5254-SLC has only 321992km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20211010T003156_20211010T003223_029066_0377E9_AD83-SLC has only 321992km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20211010T003221_20211010T003248_029066_0377E9_2099-SLC has only 321992km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20211010T003246_20211010T003313_029066_0377E9_8622-SLC has only 321992km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20211010T003311_20211010T003339_029066_0377E9_6681-SLC has only 321992km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20211010T003337_20211010T003403_029066_0377E9_2D90-SLC has only 321992km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20211010T003401_20211010T003421_029066_0377E9_C90C-SLC has only 321992km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20211016T003450_20211016T003520_040137_04C0D4_AE22-SLC has only 100742km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20211016T003517_20211016T003545_040137_04C0D4_673A-SLC has only 100742km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20211016T003543_20211016T003610_040137_04C0D4_57F6-SLC has only 100742km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20211022T003106_20211022T003134_029241_037D5A_BEC6-SLC has only 321904km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20211022T003132_20211022T003159_029241_037D5A_981F-SLC has only 321904km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20211022T003157_20211022T003223_029241_037D5A_9F6A-SLC has only 321904km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20211022T003221_20211022T003248_029241_037D5A_08CC-SLC has only 321904km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20211022T003246_20211022T003313_029241_037D5A_8DF2-SLC has only 321904km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20211022T003311_20211022T003339_029241_037D5A_12E8-SLC has only 321904km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20211022T003337_20211022T003404_029241_037D5A_3560-SLC has only 321904km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20211022T003402_20211022T003421_029241_037D5A_2ECA-SLC has only 321904km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20211028T003450_20211028T003519_040312_04C6EF_B5BA-SLC has only 100732km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20211028T003517_20211028T003545_040312_04C6EF_721B-SLC has only 100732km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20211028T003543_20211028T003610_040312_04C6EF_26ED-SLC has only 100732km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20211103T003106_20211103T003134_029416_0382BD_FBE2-SLC has only 321975km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20211103T003131_20211103T003158_029416_0382BD_0D59-SLC has only 321975km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20211103T003156_20211103T003223_029416_0382BD_944B-SLC has only 321975km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20211103T003221_20211103T003248_029416_0382BD_76F4-SLC has only 321975km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20211103T003246_20211103T003313_029416_0382BD_4A09-SLC has only 321975km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20211103T003311_20211103T003339_029416_0382BD_5F87-SLC has only 321975km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20211103T003336_20211103T003403_029416_0382BD_653A-SLC has only 321975km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20211103T003401_20211103T003421_029416_0382BD_8DC8-SLC has only 321975km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20211109T003449_20211109T003519_040487_04CD0D_585C-SLC has only 100718km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20211109T003517_20211109T003545_040487_04CD0D_D8C1-SLC has only 100718km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20211109T003543_20211109T003610_040487_04CD0D_B39A-SLC has only 100718km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20211115T003105_20211115T003133_029591_03880E_11E7-SLC has only 322001km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20211115T003131_20211115T003158_029591_03880E_8CB8-SLC has only 322001km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20211115T003156_20211115T003223_029591_03880E_8097-SLC has only 322001km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20211115T003221_20211115T003248_029591_03880E_A6E2-SLC has only 322001km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20211115T003246_20211115T003313_029591_03880E_1A61-SLC has only 322001km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20211115T003311_20211115T003338_029591_03880E_E648-SLC has only 322001km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20211115T003336_20211115T003403_029591_03880E_286B-SLC has only 322001km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20211115T003401_20211115T003421_029591_03880E_0F22-SLC has only 322001km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20211121T003449_20211121T003519_040662_04D30F_875F-SLC has only 100760km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20211121T003517_20211121T003545_040662_04D30F_01DB-SLC has only 100760km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20211121T003543_20211121T003610_040662_04D30F_71A3-SLC has only 100760km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20211127T003105_20211127T003133_029766_038D85_FCAA-SLC has only 321977km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20211127T003131_20211127T003158_029766_038D85_DAE0-SLC has only 321977km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20211127T003156_20211127T003223_029766_038D85_D375-SLC has only 321977km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20211127T003220_20211127T003247_029766_038D85_9F43-SLC has only 321977km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20211127T003245_20211127T003312_029766_038D85_4389-SLC has only 321977km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20211127T003310_20211127T003338_029766_038D85_F89C-SLC has only 321977km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20211127T003336_20211127T003403_029766_038D85_333C-SLC has only 321977km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20211127T003401_20211127T003420_029766_038D85_A6EB-SLC has only 321977km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20211203T003449_20211203T003518_040837_04D929_4B1B-SLC has only 100723km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20211203T003516_20211203T003544_040837_04D929_198F-SLC has only 100723km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20211203T003542_20211203T003609_040837_04D929_B891-SLC has only 100723km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20211209T003105_20211209T003132_029941_03930D_7EFB-SLC has only 321989km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20211209T003130_20211209T003157_029941_03930D_04C2-SLC has only 321989km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20211209T003155_20211209T003222_029941_03930D_D6EB-SLC has only 321989km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20211209T003220_20211209T003247_029941_03930D_E076-SLC has only 321989km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20211209T003245_20211209T003312_029941_03930D_DD05-SLC has only 321989km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20211209T003310_20211209T003337_029941_03930D_E4E6-SLC has only 321989km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20211209T003335_20211209T003402_029941_03930D_B5E3-SLC has only 321989km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20211209T003400_20211209T003420_029941_03930D_B479-SLC has only 321989km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20211215T003448_20211215T003518_041012_04DF34_89F5-SLC has only 100731km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20211215T003516_20211215T003544_041012_04DF34_156C-SLC has only 100731km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20211215T003542_20211215T003609_041012_04DF34_2B72-SLC has only 100731km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20211221T003104_20211221T003132_030116_039898_A766-SLC has only 321963km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20211221T003130_20211221T003157_030116_039898_6C3F-SLC has only 321963km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20211221T003154_20211221T003221_030116_039898_2800-SLC has only 321963km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20211221T003219_20211221T003246_030116_039898_1609-SLC has only 321963km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20211221T003244_20211221T003311_030116_039898_CD90-SLC has only 321963km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20211221T003309_20211221T003337_030116_039898_3E9B-SLC has only 321963km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20211221T003335_20211221T003402_030116_039898_F510-SLC has only 321963km² overlap with AOI
# Rejected scene S1B_IW_SLC__1SDV_20211221T003400_20211221T003419_030116_039898_41CC-SLC has only 321963km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20211227T003448_20211227T003517_041187_04E4EF_2012-SLC has only 100722km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20211227T003515_20211227T003543_041187_04E4EF_D345-SLC has only 100722km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20211227T003541_20211227T003608_041187_04E4EF_6D1D-SLC has only 100722km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20220108T003447_20220108T003517_041362_04EAE9_FEB0-SLC has only 100742km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20220108T003515_20220108T003542_041362_04EAE9_3EAC-SLC has only 100742km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20220108T003540_20220108T003607_041362_04EAE9_4CF3-SLC has only 100742km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20220120T003446_20220120T003516_041537_04F0A0_22E6-SLC has only 100756km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20220120T003514_20220120T003542_041537_04F0A0_CB22-SLC has only 100756km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20220120T003540_20220120T003607_041537_04F0A0_DBCE-SLC has only 100756km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20220201T003446_20220201T003516_041712_04F696_35A1-SLC has only 100754km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20220201T003513_20220201T003541_041712_04F696_C73B-SLC has only 100754km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20220201T003539_20220201T003606_041712_04F696_3875-SLC has only 100754km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20220213T003446_20220213T003516_041887_04FCAC_2C42-SLC has only 100735km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20220213T003513_20220213T003541_041887_04FCAC_A241-SLC has only 100735km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20220213T003539_20220213T003606_041887_04FCAC_CB1B-SLC has only 100735km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20220225T003446_20220225T003516_042062_0502C0_0337-SLC has only 100754km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20220225T003513_20220225T003541_042062_0502C0_57A7-SLC has only 100754km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20220225T003539_20220225T003606_042062_0502C0_BCEB-SLC has only 100754km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20220309T003446_20220309T003515_042237_0508B6_B329-SLC has only 100746km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20220309T003513_20220309T003541_042237_0508B6_5251-SLC has only 100746km² overlap with AOI
# Rejected scene S1A_IW_SLC__1SDV_20220309T003539_20220309T003606_042237_0508B6_E932-SLC has only 100746km² overlap with AOI
# 749/1726 scenes rejected for not meeting defined spatial criteria

# %%
f'We have {df_stack.shape[0]} frames in our stack'
# Out:
# 'We have 977 frames in our stack'

# %% [markdown]
# Plot acquisitions that aren't continuous (i.e. have gaps)

# %%
if not gap_scenes_dict.empty:
    gap_scenes_dict =  gap_scenes_dict.sort_values(by=['start_date'])
    for index, row in gap_scenes_dict.iterrows():
        fig, ax = plt.subplots()
        p = gpd.GeoSeries(row['geometry'])
        p.exterior.plot(color='black', ax=ax, label=row['start_date_str'][0])
        df_aoi.exterior.plot(color='red', ax=ax, label='AOI')
        plt.legend()
        plt.show

# %% [markdown]
# Plot all mosaicked acquisitions that were rejected for not meeting user-specified spatial constraints

# %%
if not rejected_scenes_dict.empty:
    rejected_scenes_dict =  rejected_scenes_dict.sort_values(by=['start_date'])
    fig, ax = plt.subplots()
    for index, row in rejected_scenes_dict.iterrows():
        p = gpd.GeoSeries(row['geometry'])
        p.exterior.plot(color='black', ax=ax)
    df_aoi.exterior.plot(color='red', ax=ax, label='AOI')
    plt.legend()

# %% [markdown]
# Plot each individual mosaicked acquisitions that were rejected for not meeting user-specified spatial constraints

# %%
if not rejected_scenes_dict.empty:
    for index, row in rejected_scenes_dict.iterrows():
        fig, ax = plt.subplots()
        p = gpd.GeoSeries(row['geometry'])
        p.exterior.plot(color='black', ax=ax, label=row['start_date_str'][0])
        df_aoi.exterior.plot(color='red', ax=ax, label='AOI')
        plt.legend()
        plt.show
# Out:
# /var/folders/13/168512yn66d8nmvt7g6jsybh0000gq/T/ipykernel_84738/3667974998.py:3: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots()

# %% [markdown]
# Plot all mosaicked acquisitions that meet user-defined spatial coverage

# %%
fig, ax = plt.subplots()

for index, row in df_stack_dict.iterrows():
    p = gpd.GeoSeries(row['geometry'])
    p.exterior.plot(color='black', ax=ax)
df_aoi.exterior.plot(color='red', ax=ax, label='AOI')
plt.legend()

# %% [markdown]
# Next, we filter the stack by month to ensure we only have SLCs we need.

# %%
df_stack_month = df_stack[df_stack.start_date.dt.month.isin(MONTHS_OF_INTEREST)]

# %% [markdown]
# We will create a list of ```min_reference_dates``` by taking the most recent date from the SLC stack ```df_stack_month``` as the start date. A range of dates with interval of ```-6 days``` is then generated until ```(START_YEAR, MONTHS_OF_INTEREST[0], 1)```.

# %%
latestSLC_date = df_stack_month.iloc[-1].start_date
min_reference_dates = [latestSLC_date - datetime.timedelta(days=i) for i in range(0, (latestSLC_date-datetime.datetime(START_YEAR,MONTHS_OF_INTEREST[0],1)).days, 6)]

# %% [markdown]
# We can now enumerate the SLC pairs that will produce the interferograms (GUNWs) based on initially defined parameters that are exposed at the top-level of this jupyter notebook.

# %%
ifg_pairs = []

for min_ref_date in tqdm(min_reference_dates):
    # because of s1 availability/gaps, we just make this huge so that we can look up slcs in the stack
    # occuring in previous years - the gaps can cause temporal jumps that you have to be mindful of
    temporal_window_days = 365*3
    temp = enumerate_ifgs_from_stack(df_stack_month,
                                     aoi,
                                     min_ref_date,
                                     enumeration_type='tile', # options are 'tile' and 'path'. 'path' processes multiple references simultaneously
                                     min_days_backward=min_days_backward,
                                     num_neighbors_ref=1,
                                     num_neighbors_sec=num_neighbors,
                                     temporal_window_days=temporal_window_days,
                                     min_tile_aoi_overlap_km2=.1,#Minimum reference tile overlap of AOI in km2
                                     min_ref_tile_overlap_perc=.1,#Relative overlap of secondary frames over reference frame
                                     minimum_ifg_area_km2=0.1,#The minimum overlap of reference and secondary in km2
                                     minimum_path_intersection_km2=.1,#Overlap of common track union with respect to AOI in km2
                                         )

    ifg_pairs += temp
# Out:
# 100%|██████████| 363/363 [04:45<00:00,  1.27it/s]

# %%
f'The number of GUNWs (likely lots of duplicates) is {len(ifg_pairs)}'
# Out:
# 'The number of GUNWs (likely lots of duplicates) is 6194'

# %% [markdown]
# # Get Dataframe

# %%
df_pairs = distill_all_pairs(ifg_pairs)

# %%
f"# of GUNWs: ' {df_pairs.shape[0]}"
# Out:
# "# of GUNWs: ' 6194"

# %% [markdown]
# As a sanity check, confirm all IFG pairs meet user-defined spatial coverage

# %% [markdown]
# Check if there are any gaps in the mosaicked IFGs, or if any are rejected for not meeting user-specified spatial constraints
#
# *NOTE: No products should be rejected at this stage. If any are, there is a problem either due to a:
# 1) Loose constraint on `azimuth_mismatch` variable whereby scenes not encompassing the entire AOI are getting passed
# 2) User-driven error
# 3) Bug in the code

# %%
df_pairs_dict = pair_spatial_check(df_pairs, aoi, azimuth_mismatch=azimuth_mismatch)
# Out:
# All 191 scenes are spatially continuous.
# 0/1924 scenes rejected for not meeting defined spatial criteria

# %%
fig, ax = plt.subplots()

for index, row in df_pairs_dict.iterrows():
    p = gpd.GeoSeries(row['geometry'])
    p.exterior.plot(color='black', ax=ax)
df_aoi.exterior.plot(color='red', ax=ax, label='AOI')
plt.legend()

# %% [markdown]
# # Deduplication Pt. 1
#
# A `GUNW` is uniquely determined by the reference and secondary IDs. We contanenate these sorted lists and generate a lossy hash to deduplicate products we may have introduced from the enumeration above.

# %%
import hashlib
import json


def get_gunw_hash_id(reference_ids: list, secondary_ids: list) -> str:
    all_ids = json.dumps([' '.join(sorted(reference_ids)),
                          ' '.join(sorted(secondary_ids))
                          ]).encode('utf8')
    hash_id = hashlib.md5(all_ids).hexdigest()
    return hash_id

# %%
def hasher(row):
    return get_gunw_hash_id(row['reference'], row['secondary'])

df_pairs['hash_id'] = df_pairs.apply(hasher, axis=1)
df_pairs.head(5)
# Out:
#                                            reference  \
# 0  [S1A_IW_SLC__1SDV_20191214T003137_20191214T003...
# 1  [S1A_IW_SLC__1SDV_20191214T003205_20191214T003...
# 2  [S1A_IW_SLC__1SDV_20191214T003230_20191214T003...
# 3  [S1A_IW_SLC__1SDV_20191214T003255_20191214T003...
# 4  [S1A_IW_SLC__1SDV_20191214T003320_20191214T003...
#
#                                            secondary reference_date  \
# 0  [S1A_IW_SLC__1SDV_20191202T003138_20191202T003...     2019-12-14
# 1  [S1A_IW_SLC__1SDV_20191202T003205_20191202T003...     2019-12-14
# 2  [S1A_IW_SLC__1SDV_20191202T003231_20191202T003...     2019-12-14
# 3  [S1A_IW_SLC__1SDV_20191202T003256_20191202T003...     2019-12-14
# 4  [S1A_IW_SLC__1SDV_20191202T003321_20191202T003...     2019-12-14
#
#   secondary_date  path_number  \
# 0     2019-12-02          165
# 1     2019-12-02          165
# 2     2019-12-02          165
# 3     2019-12-02          165
# 4     2019-12-02          165
#
#                                             geometry           startTime  \
# 0  POLYGON ((85.23335 42.35358, 85.23335 42.35358... 2019-12-02 00:31:38
# 1  POLYGON ((84.81830 40.81611, 84.81830 40.81611... 2019-12-02 00:32:05
# 2  POLYGON ((84.46003 39.32157, 84.46003 39.32157... 2019-12-02 00:32:31
# 3  POLYGON ((84.08746 37.82916, 84.08746 37.82916... 2019-12-02 00:32:56
# 4  POLYGON ((84.11599 37.95800, 84.11599 37.95800... 2019-12-02 00:33:21
#
#              stopTime                                             fileID  \
# 0 2019-12-02 00:32:07  S1A_IW_SLC__1SDV_20191214T003137_20191214T0032...
# 1 2019-12-02 00:32:33  S1A_IW_SLC__1SDV_20191214T003205_20191214T0032...
# 2 2019-12-02 00:32:58  S1A_IW_SLC__1SDV_20191214T003230_20191214T0032...
# 3 2019-12-02 00:33:23  S1A_IW_SLC__1SDV_20191214T003255_20191214T0033...
# 4 2019-12-02 00:33:47  S1A_IW_SLC__1SDV_20191214T003320_20191214T0033...
#
#    ind_col                           hash_id
# 0        0  f7395a36ac2ee1e2df79ed913e8a3500
# 1        1  bf0c05da808672a6d741dbff818e0e18
# 2        2  e1e0d5f0aae3450dabb5fd535302f700
# 3        3  286c4323c9aa8e783d37f221e2eb2b3f
# 4        4  98e6eda69db368baebc0fd00d212526d

# %%
f"# of duplicated entries: {df_pairs.duplicated(subset=['hash_id']).sum()}"
# Out:
# '# of duplicated entries: 4270'

# %%
df_pairs = df_pairs.drop_duplicates(subset=['hash_id']).reset_index(drop=True)
f"# of UNIQUE GUNWs: {df_pairs.shape[0]}"
# Out:
# '# of UNIQUE GUNWs: 1924'

# %% [markdown]
# # Viewing GUNW pairs

# %%
# start index
M = 0
# number of pairs to view
N = 5

for J in range(M, M + N):
    pair = ifg_pairs[J]

    fig, axs = plt.subplots(1, 2, sharey=True, sharex=True)

    df_ref_plot = pair['reference']
    df_sec_plot = pair['secondary']

    df_ref_plot.plot(column='start_date_str', 
                     legend=True, 
                     ax=axs[0], alpha=.15)
    df_aoi.exterior.plot(ax=axs[0], alpha=.5, color='black')
    axs[0].set_title('Reference')

    df_sec_plot.plot(column='start_date_str', 
                     legend=True, 
                     ax=axs[1], alpha=.15)
    df_aoi.exterior.plot(ax=axs[1], alpha=.5, color='black')
    
    axs[0].set_title(f'Reference {J}')
    axs[1].set_title('Secondary')

# %% [markdown]
# # Update types for Graphical Analysis
#
# We want to do some basic visualization to support the understanding if we traverse time correctly. We do some simple standard pandas manipulation.

# %%
df_pairs['reference_date'] = pd.to_datetime(df_pairs['reference_date'])
df_pairs['secondary_date'] = pd.to_datetime(df_pairs['secondary_date'])
df_pairs.head()
# Out:
#                                            reference  \
# 0  [S1A_IW_SLC__1SDV_20191214T003137_20191214T003...
# 1  [S1A_IW_SLC__1SDV_20191214T003205_20191214T003...
# 2  [S1A_IW_SLC__1SDV_20191214T003230_20191214T003...
# 3  [S1A_IW_SLC__1SDV_20191214T003255_20191214T003...
# 4  [S1A_IW_SLC__1SDV_20191214T003320_20191214T003...
#
#                                            secondary reference_date  \
# 0  [S1A_IW_SLC__1SDV_20191202T003138_20191202T003...     2019-12-14
# 1  [S1A_IW_SLC__1SDV_20191202T003205_20191202T003...     2019-12-14
# 2  [S1A_IW_SLC__1SDV_20191202T003231_20191202T003...     2019-12-14
# 3  [S1A_IW_SLC__1SDV_20191202T003256_20191202T003...     2019-12-14
# 4  [S1A_IW_SLC__1SDV_20191202T003321_20191202T003...     2019-12-14
#
#   secondary_date  path_number  \
# 0     2019-12-02          165
# 1     2019-12-02          165
# 2     2019-12-02          165
# 3     2019-12-02          165
# 4     2019-12-02          165
#
#                                             geometry           startTime  \
# 0  POLYGON ((85.23335 42.35358, 85.23335 42.35358... 2019-12-02 00:31:38
# 1  POLYGON ((84.81830 40.81611, 84.81830 40.81611... 2019-12-02 00:32:05
# 2  POLYGON ((84.46003 39.32157, 84.46003 39.32157... 2019-12-02 00:32:31
# 3  POLYGON ((84.08746 37.82916, 84.08746 37.82916... 2019-12-02 00:32:56
# 4  POLYGON ((84.11599 37.95800, 84.11599 37.95800... 2019-12-02 00:33:21
#
#              stopTime                                             fileID  \
# 0 2019-12-02 00:32:07  S1A_IW_SLC__1SDV_20191214T003137_20191214T0032...
# 1 2019-12-02 00:32:33  S1A_IW_SLC__1SDV_20191214T003205_20191214T0032...
# 2 2019-12-02 00:32:58  S1A_IW_SLC__1SDV_20191214T003230_20191214T0032...
# 3 2019-12-02 00:33:23  S1A_IW_SLC__1SDV_20191214T003255_20191214T0033...
# 4 2019-12-02 00:33:47  S1A_IW_SLC__1SDV_20191214T003320_20191214T0033...
#
#    ind_col                           hash_id
# 0        0  f7395a36ac2ee1e2df79ed913e8a3500
# 1        1  bf0c05da808672a6d741dbff818e0e18
# 2        2  e1e0d5f0aae3450dabb5fd535302f700
# 3        3  286c4323c9aa8e783d37f221e2eb2b3f
# 4        4  98e6eda69db368baebc0fd00d212526d

# %% [markdown]
# # Visualize a Date Graph from Time Series
#
# We can put this into a network Directed Graph and use some simple network functions to check connectivity.
#
# We are going to use just dates for nodes, though you could use `(ref_date, hash_id)` for nodes and then inspect connected components. That is for another notebook.

# %%
list(zip(df_pairs.reference_date, df_pairs.secondary_date))[:15]
# Out:
# [(Timestamp('2019-12-14 00:00:00'), Timestamp('2019-12-02 00:00:00')),
#  (Timestamp('2019-12-14 00:00:00'), Timestamp('2019-12-02 00:00:00')),
#  (Timestamp('2019-12-14 00:00:00'), Timestamp('2019-12-02 00:00:00')),
#  (Timestamp('2019-12-14 00:00:00'), Timestamp('2019-12-02 00:00:00')),
#  (Timestamp('2019-12-14 00:00:00'), Timestamp('2019-12-02 00:00:00')),
#  (Timestamp('2019-12-14 00:00:00'), Timestamp('2019-12-02 00:00:00')),
#  (Timestamp('2019-12-14 00:00:00'), Timestamp('2019-12-02 00:00:00')),
#  (Timestamp('2019-12-14 00:00:00'), Timestamp('2019-12-02 00:00:00')),
#  (Timestamp('2019-12-14 00:00:00'), Timestamp('2019-12-02 00:00:00')),
#  (Timestamp('2019-12-14 00:00:00'), Timestamp('2019-12-02 00:00:00')),
#  (Timestamp('2019-12-14 00:00:00'), Timestamp('2019-11-20 00:00:00')),
#  (Timestamp('2019-12-14 00:00:00'), Timestamp('2019-11-20 00:00:00')),
#  (Timestamp('2019-12-14 00:00:00'), Timestamp('2019-11-20 00:00:00')),
#  (Timestamp('2019-12-14 00:00:00'), Timestamp('2019-11-20 00:00:00')),
#  (Timestamp('2019-12-14 00:00:00'), Timestamp('2019-11-20 00:00:00'))]

# %%
unique_dates = df_pairs.reference_date.tolist() + df_pairs.secondary_date.tolist()
unique_dates = sorted(list(set(unique_dates)))
unique_dates[:5]
# Out:
# [Timestamp('2014-10-29 00:00:00'),
#  Timestamp('2014-12-16 00:00:00'),
#  Timestamp('2015-01-09 00:00:00'),
#  Timestamp('2015-02-26 00:00:00'),
#  Timestamp('2015-04-15 00:00:00')]

# %%
date2node = {date: k for (k, date) in enumerate(unique_dates)}
node2date = {k: date for (date, k) in date2node.items()}

# %%
# %matplotlib widget
G = nx.DiGraph()

edges = [(date2node[ref_date], date2node[sec_date]) 
         for (ref_date, sec_date) in zip(df_pairs.reference_date, df_pairs.secondary_date)]
G.add_edges_from(edges)

# %%
nx.draw(G)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# This function checks there is a path from the first date to the last one. The y-axis is created purely for display so doesn't really indicated anything but flow by month.

# %%
nx.has_path(G, 
            target=date2node[unique_dates[0]],
            source=date2node[unique_dates[-1]])
# Out:
# True

# %% [markdown]
# Ensure that the result above returns a ```True``` value to be able to produce a time-series.

# %%
fig, ax = plt.subplots(figsize=(15, 5))

increment = [date.month + date.day for date in unique_dates]

# source: https://stackoverflow.com/a/27852570
scat = ax.scatter(unique_dates, increment)
position = scat.get_offsets().data

pos = {date2node[date]: position[k] for (k, date) in enumerate(unique_dates)}
nx.draw_networkx_edges(G, pos=pos, ax=ax)
ax.grid('on')
ax.tick_params(axis='x',
               which='major',
               labelbottom=True,
               labelleft=True)
ymin, ymax = ax.get_ylim()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# Observe there is a gap in 2018 over are area of interest. This is where our 3 year "temporal_window_days" parameter in our enumeration was essential.

# %% [markdown]
# # Deduplication Pt. 2
#
# This is to ensure that previous processing hasn't generate any of the products we have just enumerated.
#
#
# # Check CMR
#
# This function checks the ASF DAAC if there are GUNWs with the same spatial extent and same date pairs as the ones created. At some point, we will be able to check the input SLC ids from CMR, but currently that is not possible.
#
# If you are processing a new AOI whose products have not been delivered, you can ignore this step. It is a bit time consuming as the queries are done product by product.

# %%
from s1_enumerator import duplicate_gunw_found
import concurrent
from tqdm import tqdm

n = df_pairs.shape[0]
with concurrent.futures.ThreadPoolExecutor(max_workers=15) as executor:
    results = list(tqdm(executor.map(duplicate_gunw_found, df_pairs.to_dict('records')), total=n))
# Out:
#   0%|                                                                                                                                                                                   | 0/571 [00:00<?, ?it/s]/Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
#   0%|▎                                                                                                                                                                          | 1/571 [00:03<34:16,  3.61s/it]/Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
#   2%|███▊                                                                                                                                                                      | 13/571 [00:03<01:57,  4.77it/s]/Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
#   3%|█████▋                                                                                                                                                                    | 19/571 [00:05<02:17,  4.01it/s]/Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
#   4%|███████▏                                                                                                                                                                  | 24/571 [00:05<01:37,  5.60it/s]/Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
#   5%|████████▎                                                                                                                                                                 | 28/571 [00:06<01:33,  5.81it/s]/Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
#   5%|█████████▏                                                                                                                                                                | 31/571 [00:07<01:39,  5.45it/s]/Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
#   6%|█████████▊                                                                                                                                                                | 33/571 [00:07<01:26,  6.21it/s]/Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
#   6%|██████████▍                                                                                                                                                               | 35/571 [00:07<01:51,  4.82it/s]/Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
#   6%|███████████                                                                                                                                                               | 37/571 [00:08<01:34,  5.62it/s]/Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
#   8%|█████████████▋                                                                                                                                                            | 46/571 [00:08<00:50, 10.46it/s]/Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
#   8%|██████████████▎                                                                                                                                                           | 48/571 [00:08<00:58,  8.91it/s]/Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
#   9%|██████████████▉                                                                                                                                                           | 50/571 [00:09<01:14,  7.01it/s]/Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
#   9%|███████████████▊                                                                                                                                                          | 53/571 [00:09<01:11,  7.28it/s]/Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
#  10%|████████████████▋                                                                                                                                                         | 56/571 [00:09<00:59,  8.70it/s]/Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
#  11%|█████████████████▊                                                                                                                                                        | 60/571 [00:10<00:47, 10.65it/s]/Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
#  11%|██████████████████▍                                                                                                                                                       | 62/571 [00:10<00:46, 10.85it/s]/Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
#  11%|███████████████████                                                                                                                                                       | 64/571 [00:10<00:54,  9.37it/s]/Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
#  12%|███████████████████▋                                                                                                                                                      | 66/571 [00:11<01:10,  7.15it/s]/Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
#  12%|████████████████████▊                                                                                                                                                     | 70/571 [00:11<00:55,  9.11it/s]/Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
#  13%|█████████████████████▍                                                                                                                                                    | 72/571 [00:11<00:52,  9.47it/s]/Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
#  13%|██████████████████████                                                                                                                                                    | 74/571 [00:11<00:50,  9.90it/s]/Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
#  13%|██████████████████████▋                                                                                                                                                   | 76/571 [00:11<00:43, 11.35it/s]/Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
#  14%|███████████████████████▏                                                                                                                                                  | 78/571 [00:12<01:03,  7.81it/s]/Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
#  14%|███████████████████████▊                                                                                                                                                  | 80/571 [00:13<01:39,  4.93it/s]/Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
#  15%|████████████████████████▋                                                                                                                                                 | 83/571 [00:13<01:17,  6.26it/s]/Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
#  15%|█████████████████████████▉                                                                                                                                                | 87/571 [00:13<00:55,  8.73it/s]/Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
#  16%|██████████████████████████▍                                                                                                                                               | 89/571 [00:13<00:50,  9.49it/s]/Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
#  16%|███████████████████████████▍                                                                                                                                              | 92/571 [00:13<00:47, 10.01it/s]/Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
#  16%|███████████████████████████▉                                                                                                                                              | 94/571 [00:14<00:50,  9.38it/s]/Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
#  17%|████████████████████████████▌                                                                                                                                             | 96/571 [00:14<01:16,  6.23it/s]/Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
#  17%|█████████████████████████████▍                                                                                                                                            | 99/571 [00:15<01:16,  6.13it/s]/Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
#  18%|█████████████████████████████▌                                                                                                                                           | 100/571 [00:15<01:30,  5.21it/s]/Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
#  19%|███████████████████████████████▉                                                                                                                                         | 108/571 [00:16<00:58,  7.86it/s]/Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
#  20%|█████████████████████████████████▏                                                                                                                                       | 112/571 [00:16<00:46,  9.86it/s]/Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
#  20%|█████████████████████████████████▋                                                                                                                                       | 114/571 [00:17<01:20,  5.69it/s]/Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
#  20%|██████████████████████████████████                                                                                                                                       | 115/571 [00:17<01:26,  5.28it/s]/Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
#  21%|███████████████████████████████████▏                                                                                                                                     | 119/571 [00:19<02:13,  3.40it/s]/Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
#  23%|██████████████████████████████████████▏                                                                                                                                  | 129/571 [00:20<01:13,  6.02it/s]/Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
#  24%|███████████████████████████████████████▉                                                                                                                                 | 135/571 [00:20<00:51,  8.45it/s]/Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
#  24%|████████████████████████████████████████▊                                                                                                                                | 138/571 [00:20<00:45,  9.45it/s]/Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
#  25%|█████████████████████████████████████████▍                                                                                                                               | 140/571 [00:21<00:55,  7.83it/s]/Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
#  25%|██████████████████████████████████████████                                                                                                                               | 142/571 [00:22<01:12,  5.94it/s]/Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
#  25%|██████████████████████████████████████████▌                                                                                                                              | 144/571 [00:22<01:07,  6.31it/s]/Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
#  26%|███████████████████████████████████████████▌                                                                                                                             | 147/571 [00:22<00:52,  8.06it/s]/Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
#  27%|█████████████████████████████████████████████▎                                                                                                                           | 153/571 [00:22<00:32, 12.91it/s]/Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
#  27%|██████████████████████████████████████████████▏                                                                                                                          | 156/571 [00:24<01:20,  5.13it/s]/Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
#  28%|██████████████████████████████████████████████▊                                                                                                                          | 158/571 [00:26<02:31,  2.72it/s]/Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
#  28%|███████████████████████████████████████████████▎                                                                                                                         | 160/571 [00:32<06:39,  1.03it/s]/Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
#  28%|███████████████████████████████████████████████▋                                                                                                                         | 161/571 [00:34<07:21,  1.08s/it]/Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
#  29%|████████████████████████████████████████████████▊                                                                                                                        | 165/571 [00:35<04:57,  1.36it/s]/Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
#  30%|██████████████████████████████████████████████████                                                                                                                       | 169/571 [00:39<05:15,  1.27it/s]/Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
#  30%|██████████████████████████████████████████████████▎                                                                                                                      | 170/571 [00:40<05:24,  1.23it/s]/Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
#  30%|██████████████████████████████████████████████████▌                                                                                                                      | 171/571 [00:40<05:19,  1.25it/s]/Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
#  30%|██████████████████████████████████████████████████▉                                                                                                                      | 172/571 [00:41<05:33,  1.19it/s]/Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
#  31%|███████████████████████████████████████████████████▊                                                                                                                     | 175/571 [00:41<03:16,  2.01it/s]/Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
#  32%|██████████████████████████████████████████████████████▊                                                                                                                  | 185/571 [00:42<01:15,  5.12it/s]/Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# ...
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
#  89%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▋                  | 509/571 [01:29<00:12,  5.11it/s]/Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
#  91%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▌               | 519/571 [01:29<00:05,  8.77it/s]/Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
#  91%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▏              | 521/571 [01:30<00:05,  9.04it/s]/Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
#  92%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▊              | 523/571 [01:30<00:05,  8.21it/s]/Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
#  92%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████              | 524/571 [01:31<00:09,  4.84it/s]/Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
#  93%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▌            | 529/571 [01:31<00:05,  7.76it/s]/Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
#  93%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▏           | 531/571 [01:32<00:06,  6.19it/s]/Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
#  93%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▊           | 533/571 [01:32<00:05,  6.55it/s]/Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
#  94%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▏         | 538/571 [01:32<00:03,  8.72it/s]/Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
#  95%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▊         | 540/571 [01:33<00:04,  7.52it/s]/Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
#  95%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▎       | 545/571 [01:33<00:03,  8.20it/s]/Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
#  96%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▌       | 546/571 [01:34<00:04,  6.14it/s]/Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
#  96%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▍      | 549/571 [01:34<00:03,  7.00it/s]/Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
#  97%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▌    | 556/571 [01:34<00:01, 12.59it/s]/Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
#  98%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▍   | 559/571 [01:34<00:00, 12.68it/s]/Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
#  98%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████   | 561/571 [01:35<00:01,  6.54it/s]/Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
#  99%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▌ | 566/571 [01:35<00:00,  9.44it/s]/Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# /Users/bato/opt/anaconda3/envs/s1-enumerator/lib/python3.9/site-packages/s1_enumerator/formatter.py:17: UserWarning: Dataframe is empty! Check inputs.
#   warn('Dataframe is empty! Check inputs.')
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 571/571 [01:36<00:00,  5.93it/s]

# %%
try:
    df_pairs['existing_gunw'] = [r != '' for r in results]
    df_pairs['existing_gunw_id'] = results
    total_existing_gunws = df_pairs['existing_gunw'].sum()
    print('existing_gunws: ', total_existing_gunws)
    print('Total pairs', df_pairs.shape[0])
    df_pairs_filtered = df_pairs[~df_pairs['existing_gunw']].reset_index(drop=True)
    df_pairs_filtered.drop_duplicates(subset=['hash_id'], inplace=True)
    print('after filtering, total pairs: ', df_pairs_filtered.shape[0])
except NameError:
    df_pairs_filtered = copy.deepcopy(df_pairs)
    df_pairs_filtered.drop_duplicates(subset=['hash_id'], inplace=True)
    print('after filtering, total pairs: ', df_pairs_filtered.shape[0])
# Out:
# existing_gunws:  0
# Total pairs 571

# %% [markdown]
# # Check Hyp3 Account
#
# We are now going to check
#
# 1. check products in the open s3 bucket
# 2. check running/pending jobs
#
# Notes:
#
# 1. Above, to accomplish step 1., there is some verbose code (see below). Once we automate delivery, this step will be obsolete. However, until we have delivery, we have to make sure that there are no existing products. Additionally, if we are using a separate (non-operational account), then would be good to use this.
# 2. If we are debugging products and some of our previously generated products were made incorrectly, we will want to ignore this step.

# %%
# uses .netrc; add `prompt=True` to prompt for credentials; 
hyp3_isce = hyp3_sdk.HyP3(deploy_url)
pending_jobs = hyp3_isce.find_jobs(status_code='PENDING') +  hyp3_isce.find_jobs(status_code='RUNNING')
all_jobs = hyp3_isce.find_jobs()

# %%
print(all_jobs)
# Out:
# 1487 HyP3 Jobs: 990 succeeded, 95 failed, 402 running, 0 pending.

# %% [markdown]
# ## 1. Get existing products in s3 bucket

# %%
job_data = [j.to_dict() for j in all_jobs]
job_data[0]
# Out:
# {'job_id': '9dd2b96d-6550-4739-a556-b542dcf52701',
#  'job_type': 'INSAR_ISCE_TEST',
#  'request_time': '2022-03-11T07:47:24+00:00',
#  'status_code': 'RUNNING',
#  'user_id': 'access_cloud_based_insar',
#  'name': 'LaPalma_T169',
#  'job_parameters': {'granules': ['S1A_IW_SLC__1SDV_20180210T071034_20180210T071101_020541_02324C_DAA8'],
#   'secondary_granules': ['S1B_IW_SLC__1SDV_20180204T070952_20180204T071019_009470_011083_108F']}}

# %% [markdown]
# Get bucket (there is only one)

# %%
job_data_s3 = list(filter(lambda job: 'files' in job.keys(), job_data))

# %%
bucket = job_data_s3[0]['files'][0]['s3']['bucket']

# %% [markdown]
# Get all keys

# %%
job_keys = [job['files'][0]['s3']['key'] for job in job_data_s3]

# %%
from botocore import UNSIGNED
from botocore.config import Config
s3 = boto3.resource('s3',config=Config(signature_version=UNSIGNED))
prod_bucket = s3.Bucket(bucket)

objects = list(prod_bucket.objects.all())
ncs = list(filter(lambda x: x.key.endswith('.nc'), objects))

# %% [markdown]
# Need to physically check if the products are not there (could have been deleted!)

# %%
nc_keys = [nc_ob.key for nc_ob in ncs]
jobs_with_prods_in_s3 = [job for (k, job) in enumerate(job_data_s3) if job_keys[k] in nc_keys]

# %%
slcs = [(job['job_parameters']['granules'],
         job['job_parameters']['secondary_granules']) 
        for job in jobs_with_prods_in_s3]
slcs[:2]
# Out:
# [(['S1A_IW_SLC__1SDV_20210911T173804_20210911T173823_039637_04AFA5_02E6'],
#   ['S1A_IW_SLC__1SDV_20210806T173802_20210806T173821_039112_049D8F_D6FA']),
#  (['S1A_IW_SLC__1SDV_20200624T173754_20200624T173813_033162_03D77D_6079'],
#   ['S1A_IW_SLC__1SDV_20191004T173752_20191004T173811_029312_0354D4_3B80'])]

# %%
hash_ids_of_prods_in_s3 = [get_gunw_hash_id(*slc) for slc in slcs]

# %%
f"We are removing {df_pairs_filtered['hash_id'].isin(hash_ids_of_prods_in_s3).sum()} GUNWs for submission"
# Out:
# 'We are removing 182 GUNWs for submission'

# %%
items = hash_ids_of_prods_in_s3
df_pairs_filtered = df_pairs_filtered[~df_pairs_filtered['hash_id'].isin(items)].reset_index(drop=True)
f"Current # of GUNWs: {df_pairs_filtered.shape[0]}"
# Out:
# 'Current # of GUNWs: 389'

# %% [markdown]
# ## 2. Running or Pending Jobs

# %%
pending_job_data = [j.to_dict() for j in pending_jobs]
pending_slcs = [(job['job_parameters']['granules'],
                 job['job_parameters']['secondary_granules']) 
                 for job in pending_job_data]

# %%
hash_ids_of_pending_jobs = [get_gunw_hash_id(*slc) for slc in pending_slcs]
hash_ids_of_pending_jobs[:4]
# Out:
# ['776d19a436cf6b7d6be1e62aedab34cf',
#  'c1e2134d902398de397621a6cce5c5b8',
#  '887d345fba38ff1544a2b2d504f2fa61',
#  '7b19899e0fefe8f494f3873cb854f871']

# %%
items = hash_ids_of_pending_jobs
f"We are removing {df_pairs_filtered['hash_id'].isin(items).sum()} GUNWs for submission"
# Out:
# 'We are removing 0 GUNWs for submission'

# %%
items = hash_ids_of_pending_jobs
df_pairs_filtered = df_pairs_filtered[~df_pairs_filtered['hash_id'].isin(items)].reset_index(drop=True)
f"Current # of GUNWs: {df_pairs_filtered.shape[0]}"
# Out:
# 'Current # of GUNWs: 389'

# %% [markdown]
# # Submit jobs to Hyp3

# %%
records_to_submit = df_pairs_filtered.to_dict('records')
records_to_submit[0]

# %% [markdown]
# The below puts the records in a format that we can submit to the Hyp3 API.
#
# **Note 1**: there is an index in the records to submit to ensure we don't over submit jobs for generating GUNWs. \
# **Note 2**: uncomment the code to *actually* submit the jobs.

# %%
# uses .netrc; add `prompt=True` to prompt for credentials; 
hyp3_isce = hyp3_sdk.HyP3(deploy_url)

# NOTE: we are using "INSAR_ISCE" for the `main` branch.
# Change this to "INSAR_ISCE_TEST" to use the `dev` branch, but ONLY if you know what you're doing
# chaging to dev will overwrite the product version number and make it difficult to dedup
job_type = 'INSAR_ISCE'

job_dicts = [{'name': job_name,
              'job_type': job_type,
              'job_parameters': {'granules': r['reference'],
                                 'secondary_granules': r['secondary']}} 
             # NOTE THERE IS AN INDEX - this is to submit only a subset of Jobs
             for r in records_to_submit]

# %%
# Report summary of all job parameters
print("Start date is '{}'".format(unique_dates[0]))
print("End date is '{}'".format(unique_dates[-1]))
print("GUNWs expected '{}'".format(len(job_dicts)))
print("Job Name is '{}'".format(job_name))
print("Shapefile Name is '{}'".format(aoi_shapefile.split('/')[-1]))

# %%
#UNCOMMENT TO SUBMIT
#prepared_jobs = job_dicts
#submitted_jobs = hyp3_sdk.Batch()
#for batch in hyp3_sdk.util.chunk(prepared_jobs):
#    submitted_jobs += hyp3_isce.submit_prepared_jobs(batch)

# %% [markdown]
# Query all jobs on the server

# %%
jobs = hyp3_isce.find_jobs()
print(jobs)

# %% [markdown]
# Query your particular job

# %%
jobs = hyp3_isce.find_jobs(name=job_name)
print(jobs)

# %%
# # create clean directory to deposit products in
if os.path.exists(prod_dir):
    os.remove(prod_dir)

os.mkdir(prod_dir)

# %% [markdown]
# Below, we show how to download files. The multi-threading example will download products in parallel much faster than `jobs.download_files()`.

# %%
jobs = hyp3_isce.find_jobs(name=job_name)
print(jobs)

import concurrent.futures
from tqdm import tqdm

with concurrent.futures.ThreadPoolExecutor(max_workers=10) as executor:
    results = list(tqdm(executor.map(lambda job: job.download_files(), jobs), total=len(jobs)))
